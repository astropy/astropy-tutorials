# %% [markdown]
# <a href="https://colab.research.google.com/github/adithya-ananth/Star-Pattern-Recognition/blob/main/Constellation_Coordinates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the necessary modules
from bs4 import BeautifulSoup as bs
import requests

from urllib.parse import unquote

import math
from astropy import units as u
from astropy.coordinates import SkyCoord, get_constellation

# !pip install astroquery
from astroquery.gaia import Gaia
from astroquery.simbad import Simbad
# Out:
# Requirement already satisfied: astroquery in /usr/local/lib/python3.10/dist-packages (0.4.6)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from astroquery) (1.25.2)
# Requirement already satisfied: astropy>=4.0 in /usr/local/lib/python3.10/dist-packages (from astroquery) (5.3.4)
# Requirement already satisfied: requests>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from astroquery) (2.31.0)
# Requirement already satisfied: beautifulsoup4>=4.3.2 in /usr/local/lib/python3.10/dist-packages (from astroquery) (4.12.3)
# Requirement already satisfied: html5lib>=0.999 in /usr/local/lib/python3.10/dist-packages (from astroquery) (1.1)
# Requirement already satisfied: keyring>=4.0 in /usr/lib/python3/dist-packages (from astroquery) (23.5.0)
# Requirement already satisfied: pyvo>=1.1 in /usr/local/lib/python3.10/dist-packages (from astroquery) (1.5.1)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.0->astroquery) (2.0.1.1)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.0->astroquery) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.0->astroquery) (23.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.3.2->astroquery) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery) (2024.2.2)

# %%
def find_stars(constellation_name):
  stars = []

  r = requests.get(f'https://en.wikipedia.org/wiki/List_of_stars_in_{constellation_name}')
  soup = bs(r.content, features = 'html.parser')

  # access tables
  tables = soup.find_all("tbody")

  for table in tables:
    # access each row
    rows = table.find_all("tr")

    for row in rows:
      star_name = row.find("td")

      try:
        req_name = star_name.find('a')['href']
        req_name = req_name.replace('_', ' ')

        # if the constellation is Bootes, decode the unicoded star name
        if constellation_name == "Bootes":
          req_name = unquote(req_name)
          req_name = req_name.replace('ö', 'o')

        # if the wiki link of the star has '(star)' in it
        if req_name.find('(star)') > 0:
          req_name = req_name[0:-7]

        if req_name[0:6] == '/wiki/':
          stars.append(req_name[6:])
        else:
          stars.append(star_name.text)
      except:
        pass

  return stars

# %%
# Get ra and dec values

def get_star_data(star_name):
    # get result table
    result_table = Simbad.query_object(star_name)

    # get ra and dec values and convert them
    ra_converted = float(result_table[0][1][:2])*15 + float(result_table[0][1][3:5])/4 + float(result_table[0][1][6:])*(25/6000)
    dec_converted = float(result_table[0][2][1:3]) + float(result_table[0][2][4:6])/60 + float(result_table[0][2][7:])/3600

    if result_table[0][2][0] == '-':
      dec_converted = -dec_converted

    #print(ra_converted, dec_converted)
    return SkyCoord(ra=round(ra_converted,2)*u.deg, dec=round(dec_converted,4)*u.deg)

# %%
# Define a list of 88 constellations (for reference)
constellations = [
        "Aquila", "Andromeda", "Sculptor", "Ara", "Libra", "Cetus", "Aries",
        "Scutum", "Pyxis", "Bootes", "Caelum", "Chamaeleon", "Cancer", "Capricornus", "Carina", "Cassiopeia",
        "Centaurus", "Cepheus", "Coma Berenices", "Canes Venatici", "Auriga", "Columba", "Circinus", "Crater",
        "Corona Australis", "Corona Borealis", "Corvus", "Crux", "Cygnus", "Delphinus", "Dorado", "Draco",
        "Norma", "Eridanus", "Sagitta", "Fornax", "Gemini", "Camelopardalis", "Canis Major", "Ursa Major",
        "Grus", "Hercules", "Horologium", "Hydra", "Hydrus", "Indus", "Lacerta", "Monoceros", "Lepus", "Leo",
        "Lupus", "Lynx", "Lyra", "Antlia", "Microscopium", "Musca", "Octans", "Apus", "Ophiuchus", "Orion",
        "Pavo", "Pegasus", "Pictor", "Perseus", "Equuleus", "Canis Minor", "Leo Minor", "Vulpecula",
        "Ursa Minor", "Phoenix", "Pisces", "Piscis Austrinus", "Volans", "Puppis", "Reticulum", "Sagittarius",
        "Scorpius", "Scutum", "Serpens", "Sextans", "Mensa", "Taurus", "Telescopium", "Tucana", "Triangulum",
        "Triangulum Australe", "Aquarius", "Virgo", "Vela"
    ]

# Create a list of lists, where each list contains stars obtained for each constellaition (sorted in order of decreasing brightness)
stars_list = []
for constellation in constellations:
  stars_list.append(find_stars(constellation))

# %% [markdown]
# Main Code:

# %%
# Loop over the stars and print their coordinates
table = {}
for_df = {}
for_df['Constellation'] = []
for_df['Star Name'] = []
for_df['x coordinate'] = []
for_df['y coordinate'] = []
for stars in stars_list:
    # Get the coordinate object of the first (i.e. brightest) star
    # If the first star isn't available in astropy's database, we choose the i'th star as our reference
    i = 0
    while i > -1:
      try:
        coord_one = SkyCoord.from_name(stars[i])
        break
      except:
        i = i+1

    # Get the constellation of the first star
    constellation = get_constellation(coord_one)
    print(f"{constellation}: ")
    if not constellation in table:
        table[constellation] = []

    # Define the reference frame and origin
    frame = 'icrs'
    origin = get_star_data(stars[i])

    # Get top 20 brightest stars
    for star in stars[0:20]:
      try:
        # Calculate the relative coordinates to the origin
        coord = SkyCoord.from_name(star)
        dx = (coord.ra - origin.ra).to(u.deg).value
        dy = (coord.dec - origin.dec).to(u.deg).value

        # Print the star name and coordinates
        print(f"{star} : ({dx:.2f}, {dy:.2f})")
        table[constellation].append({star: [dx.__round__(2), dy.__round__(2)]})
        for_df['Constellation'].append(constellation)
        for_df['Star Name'].append(star)
        for_df['x coordinate'].append(dx.__round__(2))
        for_df['y coordinate'].append(dy.__round__(2))
      except:
        pass




    print()

import pandas as pd, json

# Convert dictionary to JSON string
json_string = json.dumps(table)

# Save JSON string to a file
with open('data.json', 'w') as f:
    f.write(json_string)
    f.close()

df = pd.DataFrame(for_df)
df.to_csv('star_coordinates1.csv')
# Out:
# Aquila:
# Altair : (-0.00, 0.00)
# Gamma Aquilae : (-1.14, 1.74)
# Zeta Aquilae : (-11.35, 5.00)
# Theta Aquilae : (5.13, -9.69)
# Delta Aquilae : (-6.33, -5.75)
# Lambda Aquilae : (-11.14, -13.75)
# Beta Aquilae : (1.13, -2.46)
# Eta Aquilae : (0.42, -7.86)
# Epsilon Aquilae : (-12.79, 6.20)
# 12 Aquilae : (-12.28, -14.61)
# 71 Aquilae : (11.88, -9.97)
# Iota Aquilae : (-3.52, -10.15)
# Mu Aquilae : (-2.15, 4.47)
# Nu Aquilae : (-1.18, 2.89)
# Xi Aquilae : (0.86, -0.41)
# 69 Aquilae : (9.71, -11.75)
# 70 Aquilae : (11.48, -11.42)
# Kappa Aquilae : (-3.48, -15.90)
# 26 Aquilae : (-7.56, -14.28)
# 4 Aquilae : (-16.49, -6.81)
#
# Andromeda:
# Alpheratz : (-0.00, 0.00)
# Mirach : (15.33, 6.53)
# Gamma Andromedae : (28.87, 13.24)
# Delta Andromedae : (7.73, 1.77)
# Andromeda Galaxy : (8.58, 12.18)
# 51 Andromedae : (22.40, 19.54)
# Omicron Andromedae : (343.38, 13.24)
# Lambda Andromedae : (352.29, 17.37)
# Mu Andromedae : (35.26, 10.44)
# Zeta Andromedae : (9.73, -4.82)
# Upsilon Andromedae : (22.10, 12.32)
# Kappa Andromedae : (353.00, 15.24)
# Phi Andromedae : (15.28, 18.15)
# Iota Andromedae : (352.43, 14.18)
# Pi Andromedae : (7.12, 4.63)
# Epsilon Andromedae : (7.54, 0.22)
# Eta Andromedae : (12.20, -5.67)
# Sigma Andromedae : (2.48, 7.69)
# Nu Andromedae : (13.47, 4.66)
# 7 Andromedae : (346.04, 20.32)
#
# Sculptor:
# Alpha Sculptoris : (0.00, 0.00)
# Beta Sculptoris : (338.59, -8.46)
# Gamma Sculptoris : (335.06, -3.17)
# Delta Sculptoris : (342.58, 1.23)
# Eta Sculptoris : (-7.67, -3.65)
# Zeta Sculptoris : (-14.07, -0.36)
# Iota Sculptoris : (-9.27, 0.38)
# Theta Sculptoris : (-11.72, -5.78)
# Pi Sculptoris : (10.89, -2.97)
# Epsilon Sculptoris : (11.76, 4.30)
# HD 9525 : (8.58, -7.51)
# Sigma Sculptoris : (0.96, -2.19)
# HD 3059 : (-6.23, -0.20)
# Xi Sculptoris : (0.68, -9.56)
# BU Scl : (345.22, -0.13)
# HD 218434 : (332.44, 0.53)
# HD 220096 : (335.66, 2.37)
#
# Ara:
# Beta Arae : (0.00, 0.00)
# Alpha Arae : (1.64, 5.65)
# Zeta Arae : (-6.66, -0.46)
# Gamma Arae : (0.03, -0.85)
# Delta Arae : (1.45, -5.15)
# Theta Arae : (10.34, 5.44)
# Eta Arae : (-8.87, -3.51)
# Epsilon1 Arae : (-6.42, 2.37)
# Sigma Arae : (2.59, 9.02)
# Lambda Arae : (3.78, 6.11)
# Mu Arae : (-1.64, -5.04)
# Kappa Arae : (0.18, 4.90)
# Iota Arae : (-0.50, 8.06)
# Pi Arae : (3.20, 1.03)
# Epsilon2 Arae : (-5.53, 2.29)
# HD 157661 : (0.40, 9.69)
# HD 150898 : (-9.49, -2.81)
# HD 150168 : (-10.90, 5.88)
#
# Libra:
# Beta Librae : (0.00, -0.00)
# Alpha Librae : (-6.53, -6.66)
# Sigma Librae : (-3.23, -15.90)
# Upsilon Librae : (5.01, -18.75)
# Tau Librae : (5.41, -20.39)
# Gamma Librae : (4.63, -5.41)
# Theta Librae : (9.21, -7.35)
# 16 Librae : (-4.95, 5.04)
# Iota1 Librae : (-1.19, -10.41)
# 37 Librae : (4.29, -0.68)
# Kappa Librae : (6.24, -10.30)
# Delta Librae : (-4.01, 0.86)
# Epsilon Librae : (1.80, -0.94)
# 11 Librae : (-6.50, 7.08)
# 48 Librae : (10.30, -4.90)
# 42 Librae : (5.82, -14.44)
# Lambda Librae : (9.08, -10.78)
# Alpha Librae : (-6.53, -6.66)
# Mu Librae : (-5.09, 8.44)
# 49 Librae : (10.83, -7.15)
#
# Cetus:
# Beta Ceti : (-0.00, -0.00)
# Alpha Ceti : (34.67, 22.08)
# Mira : (23.94, 15.01)
# Eta Ceti : (6.25, 7.80)
# Gamma Ceti : (29.93, 21.22)
# Tau Ceti : (15.12, 2.05)
# Iota Ceti : (-6.04, 9.16)
# Theta Ceti : (10.11, 9.80)
# Zeta Ceti : (16.97, 7.65)
# Upsilon Ceti : (19.10, -3.09)
# Delta Ceti : (28.97, 18.32)
# Pi Ceti : (30.13, 4.13)
# Xi2 Ceti : (26.14, 26.45)
# Xi1 Ceti : (22.35, 26.83)
# 7 Ceti : (-7.24, -0.95)
# 2 Ceti : (-9.97, 0.65)
# Chi Ceti : (16.50, 7.30)
# Lambda Ceti : (34.03, 26.89)
# Sigma Ceti : (27.12, 2.74)
#
# Aries:
# Hamal : (0.00, 0.00)
# Beta Arietis : (-3.13, -2.65)
# 41 Arietis : (10.71, 3.80)
# Delta Arietis : (16.12, -3.74)
# HD 20644 : (18.29, 5.59)
# 39 Arietis : (10.19, 5.78)
# Gamma Arietis : (-3.41, -4.17)
# 35 Arietis : (9.07, 4.24)
# Gamma Arietis : (-3.41, -4.17)
# Lambda Arietis : (-2.31, 0.13)
# Zeta Arietis : (16.94, -2.42)
# 14 Arietis : (0.57, 2.48)
# Kappa Arietis : (-0.15, -0.81)
# Iota Arietis : (-2.45, -5.64)
# Tau2 Arietis : (18.90, -2.72)
# 38 Arietis : (9.45, -11.02)
# Epsilon Arietis : (13.01, -2.12)
# Eta Arietis : (1.41, -2.25)
# Pi Arietis : (10.53, -6.00)
# Tau1 Arietis : (18.52, -2.32)
#
# Scutum:
# Alpha Scuti : (0.00, 0.00)
# Beta Scuti : (2.99, 3.50)
# Zeta Scuti : (-2.89, -0.69)
# Gamma Scuti : (-1.50, -6.32)
# Delta Scuti : (1.77, -0.81)
# Eta Scuti : (5.47, 2.40)
# Epsilon Scuti : (2.08, -0.03)
# HD 175156 : (4.88, -7.36)
# HD 171391 : (-0.04, -2.73)
# R Scuti : (3.07, 2.54)
# V450 Sct : (-0.62, -6.62)
# HD 173638 : (2.88, -1.88)
# HD 169033 : (-3.00, -3.77)
# HD 171130 : (-0.39, -6.61)
# HD 170740 : (-0.94, -2.55)
# HD 172348 : (1.20, 0.45)
# HD 174464 : (3.94, -1.53)
# HD 174208 : (3.62, 2.33)
# V432 Sct : (-1.36, -6.34)
# HD 172831 : (1.85, 1.17)
#
# Pyxis:
# Alpha Pyxidis : (-0.00, 0.00)
# Beta Pyxidis : (-0.87, -2.12)
# Gamma Pyxidis : (1.73, 5.48)
# Kappa Pyxidis : (6.11, 7.33)
# Theta Pyxidis : (9.47, 7.22)
# Lambda Pyxidis : (9.90, 4.35)
# Zeta Pyxidis : (-0.97, 3.63)
# Delta Pyxidis : (2.98, 5.50)
# HD 73752 : (-1.12, 10.52)
# HD 75605 : (1.56, 0.41)
# Eta Pyxidis : (-1.43, 6.93)
# HD 72310 : (-3.02, 13.61)
# Epsilon Pyxidis : (6.59, 2.82)
# HD 72227 : (-3.28, 1.03)
# HD 74824 : (0.32, -3.96)
# XY Pyx : (-3.90, -1.93)
# HD 75629 : (1.61, 3.72)
# HD 73072 : (-2.03, 6.34)
# HD 74879 : (0.56, 7.80)
# HD 74706 : (0.33, 12.02)
#
# Boötes:
# Arcturus : (-0.00, 0.00)
# Epsilon Bootis : (7.33, 7.89)
# Eta Bootis : (-5.25, -0.78)
# Gamma Bootis : (4.10, 19.13)
# Delta Bootis : (14.96, 14.13)
# Beta Bootis : (11.57, 21.21)
# Rho Bootis : (4.04, 11.19)
# Zeta Bootis : (6.37, -5.45)
# Theta Bootis : (2.38, 32.67)
# Upsilon Bootis : (-6.55, -3.38)
# Lambda Bootis : (0.18, 26.91)
# Mu Bootis : (8.14, 0.16)
# Zeta Bootis : (6.37, -5.45)
# Sigma Bootis : (4.75, 10.56)
# Pi Bootis : (6.26, -2.76)
# Tau Bootis : (-7.10, -1.73)
# Psi Bootis : (12.19, 7.77)
# Kappa Bootis : (-0.55, 32.61)
# Xi Bootis : (8.93, -0.08)
# Omicron Bootis : (7.39, -2.22)
#
# Caelum:
# Alpha Caeli : (0.00, 0.00)
# Beta Caeli : (0.37, 4.72)
# Delta Caeli : (-2.43, -3.09)
# HD 30080 : (0.65, 11.10)
# HD 31093 : (2.73, 6.96)
# HD 32515 : (5.46, 10.09)
# HD 32453 : (5.25, 2.15)
# HD 30432 : (1.34, 2.51)
# HD 28454 : (-3.37, -5.08)
# HD 31529 : (3.59, 2.24)
# HD 28700 : (-2.81, -4.65)
# Lambda Caeli : (0.79, 0.80)
# HD 32820 : (5.83, 0.12)
# X Caeli : (5.97, 6.16)
# Zeta Caeli : (1.82, 11.84)
# HD 28246 : (-3.81, -2.30)
# HD 29559 : (-0.81, -0.01)
# RV Caeli : (-3.10, -0.10)
#
# Chamaleon:
# Alpha Chamaeleontis : (0.00, -0.00)
# Gamma Chamaeleontis : (34.24, -1.69)
# Beta Chamaeleontis : (59.96, -2.39)
# Theta Chamaeleontis : (0.53, -0.56)
# Epsilon Chamaeleontis : (55.28, -1.30)
# Kappa Chamaeleontis : (56.56, 0.40)
# Zeta Chamaeleontis : (18.84, -4.02)
# Iota Chamaeleontis : (16.41, -3.87)
# Eta Chamaeleontis : (5.70, -2.04)
# Pi Chamaeleontis : (49.69, 1.02)
# HD 72922 : (1.45, -3.99)
# HD 76236 : (6.85, -2.58)
# HD 114533 : (73.94, -1.53)
# HD 120213 : (84.28, -5.75)
# DR Chamaeleontis : (35.83, -2.86)
# RS Chamaeleontis : (6.17, -2.15)
#
# Cancer:
# Beta Cancri : (-0.00, 0.00)
# Delta Cancri : (7.04, 8.97)
# Iota Cancri : (7.54, 19.57)
# Alpha Cancri : (10.49, 2.67)
# Gamma Cancri : (6.69, 12.28)
# Zeta Cancri : (-1.08, 8.46)
# 8 Cancri : (-2.86, 3.93)
# Chi Cancri : (0.89, 18.03)
# Xi Cancri : (13.21, 12.86)
# Omicron1 Cancri : (10.18, 6.14)
# Rho2 Cancri : (9.79, 18.74)
# Sigma3 Cancri : (10.76, 23.23)
# Kappa Cancri : (12.81, 1.48)
# Theta Cancri : (3.77, 8.91)
# Eta Cancri : (4.05, 11.26)
# 82 Cancri : (14.68, 5.76)
# 57 Cancri : (9.43, 21.39)
# Tau Cancri : (12.87, 20.47)
# 60 Cancri : (9.85, 2.44)
#
# Capricornus:
# Delta Capricorni : (0.00, 0.00)
# Beta Capricorni : (-21.51, 1.35)
# Gamma Capricorni : (-1.74, -0.54)
# Zeta Capricorni : (-5.09, -6.28)
# Theta Capricorni : (-10.27, -1.11)
# Omega Capricorni : (-13.80, -10.79)
# Psi Capricorni : (-15.24, -9.14)
# Iota Capricorni : (-6.20, -0.71)
# Alpha1 Capricorni : (-22.35, 3.62)
# 24 Capricorni : (-9.98, -8.88)
# 36 Capricorni : (-4.58, -5.68)
# Epsilon Capricorni : (-2.49, -3.34)
# Kappa Capricorni : (-1.10, -2.74)
# Rho Capricorni : (-19.54, -1.69)
# Eta Capricorni : (-10.66, -3.73)
# Pi Capricorni : (-19.93, -2.08)
# 46 Capricorni : (-0.51, 7.04)
#
# Carina:
# Canopus : (-0.00, 0.00)
# Beta Carinae : (42.31, -17.02)
# Epsilon Carinae : (29.64, -6.81)
# Iota Carinae : (43.28, -6.58)
# Theta Carinae : (64.75, -11.70)
# Upsilon Carinae : (50.79, -12.38)
# Omega Carinae : (57.44, -17.34)
# PP Carinae : (62.02, -8.99)
# V337 Carinae : (58.28, -8.64)
# V357 Carinae : (41.75, -6.27)
# Chi Carinae : (23.20, -0.29)
# HD 84810 : (50.32, -9.81)
# HD 94510 : (67.38, -6.16)
# HD 90853 : (60.98, -6.04)
# HD 76728 : (37.77, -7.95)
# V382 Carinae : (71.16, -6.28)
# HD 79447 : (41.83, -9.62)
# HR 4102 : (60.11, -21.34)
# HD 83183 : (47.62, -6.53)
# V343 Carinae : (34.16, -7.07)
#
# Cassiopeia:
# Alpha Cassiopeiae : (-0.00, 0.00)
# Beta Cassiopeiae : (-7.84, 2.61)
# Gamma Cassiopeiae : (4.05, 4.18)
# Delta Cassiopeiae : (11.32, 3.70)
# Epsilon Cassiopeiae : (18.47, 7.13)
# Eta Cassiopeiae : (2.15, 1.28)
# Zeta Cassiopeiae : (-0.89, -2.64)
# 50 Cassiopeiae : (20.73, 15.88)
# Kappa Cassiopeiae : (-1.88, 6.39)
# Theta Cassiopeiae : (7.65, -1.39)
# Iota Cassiopeiae : (27.14, 10.87)
# Omicron Cassiopeiae : (1.05, -8.25)
# 48 Cassiopeiae : (20.36, 14.37)
# Rho Cassiopeiae : (348.47, 0.96)
# Upsilon2 Cassiopeiae : (4.04, 2.64)
# Chi Cassiopeiae : (13.35, 2.69)
# Psi Cassiopeiae : (11.35, 11.59)
# Lambda Cassiopeiae : (-2.19, -2.02)
# Xi Cassiopeiae : (0.39, -6.02)
# HR 244 : (3.14, 4.59)
#
# Centaurus:
# Alpha Centauri : (-0.00, 0.00)
# Beta Centauri : (-8.96, 0.47)
# Alpha Centauri : (-0.00, 0.00)
# Theta Centauri : (-8.25, 24.47)
# Gamma Centauri : (-29.54, 11.88)
# Epsilon Centauri : (-14.95, 7.37)
# Eta Centauri : (-1.04, 18.68)
# Zeta Centauri : (-11.04, 13.55)
# Delta Centauri : (-37.83, 10.12)
# Iota Centauri : (-19.77, 24.13)
# Lambda Centauri : (-45.97, -2.18)
# Kappa Centauri : (4.87, 18.73)
# Nu Centauri : (-19.10, -3.74)
# Mu Centauri : (-36.70, 16.37)
# Phi Centauri : (-10.35, 18.74)
# Tau Centauri : (-30.49, 12.30)
# Upsilon1 Centauri : (-10.25, 16.04)
# Pi Centauri : (-49.67, 6.35)
# HD 117440 : (-17.16, 21.43)
# Sigma Centauri : (-32.91, 10.61)
#
# Cepheus:
# Alpha Cephei : (0.00, -0.00)
# Gamma Cephei : (35.20, 15.05)
# Beta Cephei : (2.52, 7.98)
# Zeta Cephei : (13.07, -4.38)
# Eta Cephei : (-8.32, -0.75)
# Iota Cephei : (22.78, 3.61)
# Delta Cephei : (17.65, -4.17)
# Epsilon Cephei : (14.12, -5.54)
# Theta Cephei : (-12.24, 0.41)
# Mu Cephei : (16.27, -4.90)
# 2 Ursae Minoris : (-302.45, 23.67)
# Nu Cephei : (3.34, -1.09)
# Kappa Cephei : (-17.42, 15.13)
# Pi Cephei : (27.33, 12.80)
# Xi Cephei : (11.31, 2.04)
# HR 7955 : (-8.30, -5.01)
# 11 Cephei : (5.84, 8.73)
# HD 217382 : (23.96, 21.76)
# Omicron Cephei : (30.02, 5.53)
# 9 Cephei : (4.84, -0.50)
#
# Coma Berenices:
# Beta Comae Berenices : (-0.00, -0.00)
# Alpha Comae Berenices : (-0.47, -10.35)
# Gamma Comae Berenices : (-11.24, 0.39)
# 11 Comae Berenices : (-12.79, -10.09)
# 36 Comae Berenices : (-3.24, -10.47)
# 12 Comae Berenices : (-12.34, -2.03)
# 23 Comae Berenices : (-9.26, -5.25)
# 41 Comae Berenices : (-1.18, -0.25)
# 35 Comae Berenices : (-4.65, -6.63)
# 37 Comae Berenices : (-2.90, 2.91)
# 14 Comae Berenices : (-11.37, -0.61)
# 7 Comae Berenices : (-13.88, -3.93)
# 31 Comae Berenices : (-5.05, -0.34)
# 16 Comae Berenices : (-11.22, -1.05)
# HD 106760 : (-13.84, 5.18)
# 24 Comae Berenices : (-9.19, -9.50)
# 6 Com : (-13.97, -12.98)
# 27 Com : (-6.31, -11.30)
# 13 Comae Berenices : (-11.89, -1.78)
# Alpha Comae Berenices : (-0.47, -10.35)
#
# Canes Venatici:
# Cor Caroli : (-0.00, -0.00)
# Beta Canum Venaticorum : (-5.57, 3.04)
# 24 Canum Venaticorum : (9.60, 10.70)
# 20 Canum Venaticorum : (5.38, 2.25)
# AW Canum Venaticorum : (13.94, -3.87)
# 5 Canum Venaticorum : (-8.00, 13.24)
# 25 Canum Venaticorum : (10.36, -2.02)
# HR 5110 : (9.69, -1.14)
# HD 115004 : (4.42, 1.83)
# 6 Canum Venaticorum : (-7.55, 0.70)
# 21 Canum Venaticorum : (5.55, 11.36)
# 14 CVn : (2.43, -2.52)
# 3 CVn : (-9.06, 10.67)
# HD 109317 : (-5.60, -5.07)
# La Superba : (-2.73, 7.12)
# HD 120164 : (12.74, 0.22)
# 23 CVn : (6.07, 1.83)
# Alpha1 Canum Venaticorum : (-0.01, -0.00)
# HD 120420 : (13.15, -7.13)
# HD 113847 : (2.46, 6.95)
#
# Auriga:
# Capella : (0.00, -0.00)
# Beta Aurigae : (10.71, -1.05)
# Theta Aurigae : (10.76, -8.79)
# Iota Aurigae : (-4.92, -12.83)
# Epsilon Aurigae : (-3.68, -2.17)
# Eta Aurigae : (-2.54, -4.76)
# Zeta Aurigae : (-3.55, -4.92)
# Delta Aurigae : (10.71, 8.29)
# Nu Aurigae : (-1.91, -17.32)
# Pi Aurigae : (10.81, -0.06)
# Kappa Aurigae : (14.67, -16.50)
# Tau Aurigae : (8.12, -6.82)
# 16 Aurigae : (0.37, -12.63)
# Lambda Aurigae : (0.62, -5.90)
# Chi Aurigae : (4.01, -13.81)
# Upsilon Aurigae : (8.59, -8.69)
# 2 Aurigae : (-6.01, -9.29)
# Psi2 Aurigae : (20.66, -3.51)
# Mu Aurigae : (10.27, -16.41)
# 63 Aurigae : (28.74, -6.68)
#
# Columba:
# Alpha Columbae : (0.00, -0.00)
# Beta Columbae : (2.83, -1.69)
# Delta Columbae : (10.62, 0.64)
# Epsilon Columbae : (-2.11, -1.40)
# Eta Columbae : (4.88, -8.74)
# Gamma Columbae : (4.47, -1.21)
# Kappa Columbae : (9.23, -1.07)
# Omicron Columbae : (-5.54, -0.82)
# Lambda Columbae : (3.37, 0.27)
# Xi Columbae : (3.96, -3.05)
# Theta Columbae : (6.97, -3.18)
# HD 46568 : (13.18, -3.62)
# WZ Columbae : (0.65, -0.59)
# HD 46815 : (13.55, -2.16)
# HD 37811 : (0.05, 1.44)
# HD 36848 : (-1.70, -4.44)
# Pi2 Columbae : (7.06, -8.08)
# Sigma Columbae : (4.18, 2.69)
#
# Circinus:
# Alpha Circini : (-0.00, -0.00)
# Beta Circini : (8.75, 6.17)
# Gamma Circini : (10.21, 5.65)
# Epsilon Circini : (8.78, 1.36)
# Delta Circini : (8.61, 4.02)
# Theta Circini : (3.55, 2.19)
# Eta Circini : (5.57, 0.94)
# HD 131342 : (3.26, 4.86)
# HD 129422 : (0.69, 2.10)
# HD 135591 : (9.07, 4.48)
# HD 125835 : (-4.35, -3.22)
# HD 136359 : (10.16, 4.32)
# HD 124471 : (-6.47, -1.61)
# HD 120404 : (-12.68, -4.43)
# HD 120913 : (-11.93, -2.68)
# HD 135160 : (8.52, 4.07)
# HD 126862 : (-2.81, -2.74)
# HD 126241 : (-3.85, -0.85)
# CO Cir : (1.56, -1.62)
# AX Circini : (2.52, 1.17)
#
# Crater:
# Delta Crateris : (-0.00, -0.00)
# Gamma Crateris : (1.38, -2.91)
# Alpha Crateris : (-4.90, -3.52)
# Beta Crateris : (-1.93, -8.05)
# Theta Crateris : (4.33, 4.98)
# Zeta Crateris : (6.35, -3.57)
# Epsilon Crateris : (1.31, 3.92)
# Lambda Crateris : (1.00, -4.00)
# Eta Crateris : (9.16, -2.37)
# Iota Crateris : (4.83, 1.58)
# HD 95808 : (-4.03, 3.48)
# HD 94481 : (-6.27, 1.02)
# HD 99922 : (2.57, -9.69)
# HD 95314 : (-4.79, 0.70)
# HD 95234 : (-4.96, -1.58)
# Kappa Crateris : (1.95, 2.42)
# HD 100343 : (3.36, 6.95)
# HD 100418 : (3.47, -1.50)
# HD 96220 : (-3.45, 3.69)
# Psi Crateris : (-1.71, -3.72)
#
# Corona Australis:
# Beta Coronae Australis : (-0.00, 0.00)
# Alpha Coronae Australis : (-0.14, 1.44)
# Gamma Coronae Australis : (-0.91, 2.28)
# Delta Coronae Australis : (-0.42, -1.16)
# Theta Coronae Australis : (-9.13, -2.97)
# Zeta Coronae Australis : (-1.73, -2.75)
# Epsilon Coronae Australis : (-2.83, 2.23)
# HD 165189 : (-15.80, -4.08)
# Gamma Coronae Australis : (-0.91, 2.28)
# HD 168592 : (-11.93, 0.68)
# Lambda Coronae Australis : (-6.56, 1.02)
# HD 170642 : (-9.42, -0.36)
# Mu Coronae Australis : (-16.59, 0.22)
# HD 168905 : (-11.43, -4.77)
# HD 175219 : (-3.44, -3.37)
# V686 Coronae Australis : (-3.34, 2.00)
# HD 172991 : (-6.27, -0.35)
# V718 Coronae Australis : (-7.61, -3.85)
# HD 167096 : (-13.54, -4.87)
# Eta1 Coronae Australis : (-5.30, -4.34)
#
# Corona Borealis:
# Alpha Coronae Borealis : (0.00, -0.00)
# Beta Coronae Borealis : (-1.71, 2.39)
# Gamma Coronae Borealis : (2.02, -0.42)
# Theta Coronae Borealis : (-0.44, 4.64)
# Epsilon Coronae Borealis : (5.73, 0.16)
# Delta Coronae Borealis : (3.73, -0.65)
# Zeta Coronae Borealis : (1.17, 9.92)
# Tau Coronae Borealis : (8.57, 9.78)
# Kappa Coronae Borealis : (4.14, 8.94)
# Xi Coronae Borealis : (11.85, 4.18)
# Iota Coronae Borealis : (6.69, 3.14)
# Eta Coronae Borealis : (-2.87, 3.57)
# Rho Coronae Borealis : (6.59, 6.59)
# Lambda Coronae Borealis : (5.28, 11.23)
# Omicron Coronae Borealis : (-3.63, 2.90)
# Sigma Coronae Borealis : (10.00, 7.14)
# Pi Coronae Borealis : (2.33, 5.80)
#
# Corvus:
# Gamma Corvi : (0.00, -0.00)
# Beta Corvi : (4.65, -5.85)
# Delta Corvi : (3.52, 1.03)
# Epsilon Corvi : (-1.42, -5.08)
# Alpha Corvi : (-1.85, -7.19)
# Eta Corvi : (4.07, 1.35)
# HD 107418 : (1.28, 3.98)
# VV Corvi : (6.37, 4.53)
# Zeta Corvi : (1.19, -4.67)
# 31 Crateris : (-3.74, -2.12)
# 3 Corvi : (-1.18, -6.06)
# HD 109272 : (4.44, 4.71)
# HD 108821 : (3.62, -6.15)
# 6 Corvi : (1.89, -7.30)
# HD 109141 : (4.20, 3.68)
# HD 106485 : (-0.20, -3.30)
# HD 107295 : (1.09, -4.63)
# HD 109931 : (5.74, -0.71)
# HD 110385 : (6.51, -2.22)
# HD 106819 : (0.31, 0.85)
#
# Crux :
# Beta Crucis : (0.00, 0.00)
# Alpha Crucis : (-5.28, -3.41)
# Gamma Crucis : (-4.14, 2.58)
# Alpha Crucis : (-5.28, -3.41)
# Delta Crucis : (-8.14, 0.94)
# Epsilon Crucis : (-6.59, -0.71)
# Zeta Crucis : (-7.32, -4.31)
# Eta Crucis : (-10.21, -4.92)
# Theta1 Crucis : (-11.17, -3.62)
# HD 110956 : (-0.34, 3.20)
# Lambda Crucis : (1.73, 0.54)
# Iota Crucis : (-0.52, -1.29)
# Theta2 Crucis : (-10.85, -3.48)
# Alpha Crucis : (-5.28, -3.41)
# CH Crucis : (-1.44, 0.00)
# HD 110432 : (-1.22, -3.37)
# HD 112244 : (2.06, 2.85)
# HD 107696 : (-6.22, 2.01)
#
# Cygnus:
# Deneb : (-0.00, 0.00)
# Gamma Cygni : (-4.80, -5.02)
# Epsilon Cygni : (1.19, -11.31)
# Delta Cygni : (-14.12, -0.15)
# Albireo : (-17.68, -17.32)
# Zeta Cygni : (7.87, -15.05)
# Xi Cygni : (5.87, -1.35)
# Tau Cygni : (8.34, -7.23)
# Iota Cygni : (-17.93, 6.45)
# Kappa Cygni : (-21.08, 8.09)
# Omicron1 Cygni : (-6.95, 1.46)
# Eta Cygni : (-11.28, -10.20)
# Nu Cygni : (-12.45, -6.16)
# Omicron2 Cygni : (-6.49, 2.43)
# Rho Cygni : (13.14, 0.31)
# 41 Cygni : (-3.01, -14.91)
# 52 Cygni : (1.06, -14.56)
# Sigma Cygni : (8.99, -5.89)
# Pi2 Cygni : (16.34, 4.03)
# 33 Cygni : (-7.01, 11.29)
#
# Delphinus:
# Beta Delphini : (-0.00, -0.00)
# Alpha Delphini : (0.52, 1.32)
# Epsilon Delphini : (-1.09, -3.29)
# Gamma Delphini : (2.27, 1.53)
# Delta Delphini : (1.47, 0.48)
# Zeta Delphini : (-0.56, 0.08)
# Rho Aquilae : (-5.82, 0.60)
# Kappa Delphini : (0.39, -4.51)
# Gamma Delphini : (2.27, 1.53)
# 17 Delphini : (4.51, -0.87)
# Eta Delphini : (-0.90, -1.57)
# Iota Delphini : (0.06, -3.22)
# 18 Delphini : (5.22, -3.76)
# 16 Delphini : (4.52, -2.03)
# 13 Delphini : (2.56, -8.59)
# Theta Delphini : (0.29, -1.28)
# HD 200044 : (5.73, 4.73)
# HD 193472 : (-4.39, -1.05)
# HD 196775 : (0.38, 1.24)
# 10 Delphini : (0.93, -0.01)
#
# Dorado:
# Alpha Doradus : (-0.00, 0.00)
# Beta Doradus : (14.91, -7.44)
# Gamma Doradus : (-4.49, 3.56)
# Delta Doradus : (17.69, -10.69)
# HD 40409 : (20.03, -8.04)
# Zeta Doradus : (7.88, -2.43)
# Theta Doradus : (9.94, -12.14)
# Eta2 Doradus : (24.31, -10.54)
# Epsilon Doradus : (18.97, -11.86)
# Lambda Doradus : (13.08, -3.87)
# WZ Doradus : (8.39, -8.35)
# Kappa Doradus : (2.59, -4.69)
# G Doradus : (14.75, -9.18)
# Pi2 Doradus : (27.87, -14.65)
# Pi1 Doradus : (27.16, -14.94)
# R Doradus : (0.69, -7.03)
# Eta1 Doradus : (23.04, -10.99)
# HD 36584 : (13.25, -13.58)
# HD 27604 : (-3.83, 2.18)
#
# Draco:
# Gamma Draconis : (0.00, -0.00)
# Eta Draconis : (-23.15, 10.03)
# Beta Draconis : (-6.54, 0.81)
# Delta Draconis : (18.99, 16.17)
# Zeta Draconis : (-11.95, 14.23)
# Iota Draconis : (-37.92, 7.48)
# Chi Draconis : (6.11, 21.24)
# Thuban : (-58.05, 12.89)
# Xi Draconis : (-0.77, 5.38)
# Lambda Draconis : (-96.30, 17.84)
# Epsilon Draconis : (27.89, 18.78)
# Kappa Draconis : (-80.78, 18.30)
# Theta Draconis : (-28.68, 7.08)
# Phi Draconis : (6.04, 19.85)
# HD 81817 : (-124.88, 29.84)
# Tau Draconis : (19.74, 21.87)
# Rho Draconis : (31.55, 16.38)
# Psi1 Draconis : (-3.66, 20.66)
# 10 Draconis : (-61.29, 13.23)
# Pi Draconis : (21.02, 14.23)
#
# Norma:
# Gamma2 Normae : (0.00, -0.00)
# Epsilon Normae : (1.84, 2.60)
# Iota1 Normae : (-4.08, -7.62)
# Eta Normae : (-4.16, 0.93)
# Delta Normae : (-3.34, 4.98)
# Mu Normae : (0.25, -5.97)
# Kappa Normae : (-1.59, -4.47)
# Gamma1 Normae : (-0.71, 0.09)
# Theta Normae : (-1.15, 2.78)
# HD 147152 : (0.66, 0.58)
# QU Normae : (2.47, 3.91)
# HD 139129 : (-10.25, -2.22)
# Lambda Normae : (-0.14, 7.48)
# V368 Nor : (-0.78, -3.66)
# Iota2 Normae : (-2.63, -7.78)
# HD 145782 : (-1.00, -7.76)
# HD 147977 : (2.10, -8.44)
# V360 Nor : (-7.18, -4.90)
# HD 146690 : (0.15, -4.98)
# HD 141168 : (-7.43, -3.05)
#
# Eridanus:
# Achernar : (-0.00, 0.00)
# Beta Eridani : (52.53, 52.15)
# Theta Eridani : (20.14, 16.93)
# Gamma Eridani : (35.08, 43.73)
# Delta Eridani : (31.38, 47.47)
# Upsilon4 Eridani : (40.04, 23.44)
# Phi Eridani : (9.70, 5.72)
# Chi Eridani : (4.56, 5.63)
# Tau4 Eridani : (25.45, 35.48)
# Epsilon Eridani : (28.80, 47.78)
# Upsilon2 Eridani : (44.46, 26.67)
# 53 Eridani : (45.12, 42.93)
# Eta Eridani : (19.68, 48.34)
# Upsilon3 Eridani : (41.58, 23.22)
# Mu Eridani : (17.61, 41.94)
# Omicron1 Eridani : (38.54, 50.40)
# Tau3 Eridani : (21.17, 33.61)
# Iota Eridani : (15.74, 17.38)
# HD 24160 : (32.93, 21.04)
#
# Sagitta:
# Gamma Sagittae : (-0.00, 0.00)
# Delta Sagittae : (-2.84, -0.96)
# Alpha Sagittae : (-4.67, -1.48)
# Beta Sagittae : (-4.43, -2.02)
# Zeta Sagittae : (-2.45, -0.35)
# Eta Sagittae : (1.60, 0.50)
# 13 Sagittae : (0.32, -1.98)
# 11 Sagittae : (-0.25, -2.70)
# 1 Sagittae : (-10.87, 1.74)
# Epsilon Sagittae : (-5.37, -3.03)
# S Sagittae : (-0.68, -2.86)
# 15 Sagittae : (1.34, -2.42)
# HD 193579 : (5.40, -1.70)
# HD 190211 : (1.13, -0.99)
# HD 180242 : (-10.93, 0.71)
# HD 178428 : (-12.70, -2.64)
# HD 177199 : (-13.97, 0.17)
# 18 Sagittae : (4.39, 2.11)
# 9 Sagittae : (-1.60, -0.82)
# HD 191814 : (3.07, 1.64)
#
# Fornax:
# Alpha Fornacis : (-0.00, -0.00)
# Beta Fornacis : (-5.75, -3.42)
# Omega Fornacis : (-9.56, 0.76)
# Delta Fornacis : (7.54, -2.95)
# Phi Fornacis : (-11.01, -4.82)
# Kappa Fornacis : (-12.38, 5.17)
# Pi Fornacis : (-17.71, -1.01)
# Gamma2 Fornacis : (-5.54, 1.05)
# Eta3 Fornacis : (-5.35, -6.69)
# Rho Fornacis : (8.96, -1.18)
# AI For : (1.88, 4.86)
# Zeta Fornacis : (-3.12, 3.71)
# Chi2 Fornacis : (3.87, -6.69)
# Iota1 Fornacis : (-8.98, -1.06)
# Lambda2 Fornacis : (-8.78, -5.59)
# Iota2 Fornacis : (-8.44, -1.21)
# Epsilon Fornacis : (-2.61, 0.90)
# Lambda1 Fornacis : (-9.74, -5.66)
#
# Gemini:
# Pollux : (-0.00, -0.00)
# Castor : (-2.68, 3.86)
# Gamma Geminorum : (-16.90, -11.63)
# Mu Geminorum : (-11.48, -13.95)
# Castor : (-2.68, 3.86)
# Epsilon Geminorum : (-15.35, -2.90)
# Eta Geminorum : (-22.61, -5.52)
# Xi Geminorum : (-15.01, -15.13)
# Delta Geminorum : (-6.30, -6.04)
# Kappa Geminorum : (-0.22, -3.63)
# Lambda Geminorum : (-6.81, -11.49)
# Theta Geminorum : (-13.13, 5.94)
# Iota Geminorum : (-4.90, -0.23)
# Zeta Geminorum : (-10.30, -7.46)
# Upsilon Geminorum : (-2.35, -1.13)
# Nu Geminorum : (-25.79, -0.50)
# 1 Geminorum : (-25.30, -4.76)
# Rho Geminorum : (-4.05, 3.76)
# Sigma Geminorum : (-0.50, 0.86)
# Tau Geminorum : (-8.55, 2.22)
#
# Camelopardalis:
# Beta Camelopardalis : (0.00, 0.00)
# CS Camelopardalis : (-23.58, -0.50)
# Alpha Camelopardalis : (-2.34, 5.90)
# BE Camelopardalis : (-18.47, 5.08)
# 7 Camelopardalis : (-1.53, -6.69)
# CE Camelopardalis : (-23.37, -1.56)
# HD 49878 : (29.17, 16.54)
# Gamma Camelopardalis : (-18.26, 10.89)
# BK Camelopardalis : (-25.85, 5.21)
# HD 42818 : (18.86, 8.88)
# HD 23089 : (-19.34, 2.90)
# VZ Camelopardalis : (36.92, 21.97)
# HD 24479 : (-16.49, 2.63)
# HD 24480 : (-16.57, 0.67)
# HD 25291 : (-14.74, -1.29)
# BD Camelopardalis : (-20.31, 2.77)
# 3 Camelopardalis : (-5.87, -7.36)
# HD 33564 : (4.79, 18.79)
# HD 21447 : (-23.35, -4.99)
# 43 Camelopardalis : (27.58, 8.45)
#
# Canis Major:
# Sirius : (-0.00, -0.00)
# Epsilon Canis Majoris : (3.37, -12.26)
# Delta Canis Majoris : (5.81, -9.68)
# Beta Canis Majoris : (-5.62, -1.24)
# Eta Canis Majoris : (9.73, -12.59)
# Zeta Canis Majoris : (-6.21, -13.35)
# Omicron2 Canis Majoris : (4.47, -7.12)
# Sigma Canis Majoris : (4.14, -11.22)
# Kappa Canis Majoris : (1.17, -15.79)
# Omicron1 Canis Majoris : (2.24, -7.47)
# Omega Canis Majoris : (7.41, -10.06)
# Theta Canis Majoris : (2.26, 4.68)
# Gamma Canis Majoris : (4.65, 1.08)
# Xi1 Canis Majoris : (-3.33, -6.70)
# Iota Canis Majoris : (2.74, -0.34)
# Tau Canis Majoris : (8.39, -8.24)
# 27 Canis Majoris : (7.27, -9.64)
# Lambda Canis Majoris : (-4.25, -15.86)
#
# Ursa Major:
# Alioth : (-0.00, 0.00)
# Dubhe : (-27.58, 5.79)
# Alkaid : (13.38, -6.65)
# Mizar : (7.47, -1.03)
# Merak : (-28.05, 0.42)
# Phecda : (-15.05, -2.27)
# Psi Ursae Majoris : (-26.09, -11.46)
# Mu Ursae Majoris : (-19.61, -17.19)
# Theta Ursae Majoris : (-50.30, -4.28)
# Iota Ursae Majoris : (-58.71, -7.92)
# Delta Ursae Majoris : (-9.65, 1.07)
# Omicron Ursae Majoris : (-65.94, 4.76)
# Lambda Ursae Majoris : (-39.24, -13.05)
# Nu Ursae Majoris : (-30.26, 1.74)
# Kappa Ursae Majoris : (-57.60, -8.80)
# 23 Ursae Majoris : (-50.63, 7.10)
# Chi Ursae Majoris : (-17.00, -8.18)
# Upsilon Ursae Majoris : (-45.76, 3.08)
# Mizar : (7.47, -1.03)
# Alcor : (7.80, -0.97)
#
# Grus:
# Alpha Gruis : (-0.00, 0.00)
# Beta Gruis : (8.61, 0.08)
# Gamma Gruis : (-3.58, 9.60)
# Epsilon Gruis : (10.08, -4.36)
# Iota Gruis : (15.53, 1.71)
# Delta1 Gruis : (5.26, 3.47)
# Zeta Gruis : (13.16, -5.79)
# Delta2 Gruis : (5.38, 3.21)
# Theta Gruis : (14.66, 3.44)
# Lambda Gruis : (-0.53, 7.42)
# Rho Gruis : (8.81, 5.55)
# Eta Gruis : (9.35, -6.54)
# Xi Gruis : (-9.04, 5.78)
# HD 211415 : (2.51, -6.67)
# Kappa Gruis : (14.11, -7.00)
# HD 216149 : (10.70, 7.80)
# HD 208321 : (-2.97, 9.71)
#
# Hercules:
# Beta Herculis : (0.00, 0.00)
# Zeta Herculis : (2.77, 10.11)
# Delta Herculis : (11.21, 3.35)
# Pi Herculis : (11.21, 15.32)
# Alpha Herculis : (11.11, -7.10)
# Mu Herculis : (1.70, 21.26)
# Eta Herculis : (3.17, 17.43)
# Xi Herculis : (21.89, 7.76)
# Gamma Herculis : (-2.07, -2.34)
# Iota Herculis : (17.32, 24.52)
# Omicron Herculis : (24.34, 7.27)
# 109 Herculis : (28.37, 0.28)
# Theta Herculis : (21.51, 15.76)
# Tau Herculis : (-2.61, 24.82)
# Epsilon Herculis : (7.52, 9.44)
# 110 Herculis : (33.87, -0.94)
# Sigma Herculis : (0.98, 20.95)
# Phi Herculis : (-5.36, 23.45)
# 95 Her : (22.83, 0.11)
# 111 Herculis : (34.21, -3.31)
#
# Horologium:
# Alpha Horologii : (0.00, 0.00)
# R Horologii : (-20.03, -7.60)
# Delta Horologii : (-0.79, 0.30)
# Beta Horologii : (-18.80, -21.78)
# Zeta Horologii : (-23.33, -12.26)
# Eta Horologii : (-24.15, -10.25)
# HD 27588 : (1.32, -1.97)
# Lambda Horologii : (-27.28, -18.02)
# Iota Horologii : (-22.86, -8.51)
# HD 22231 : (-10.35, -8.08)
# TW Horologii : (-15.36, -15.03)
# HD 23719 : (-7.18, -5.07)
# Gamma Horologii : (-22.14, -21.41)
# HD 14641 : (-28.52, -13.65)
# HD 20640 : (-14.14, -5.46)
# HD 24706 : (-5.11, -4.60)
# TU Hor : (-10.85, -5.08)
# HD 18185 : (-20.42, -20.62)
#
# Hydra:
# Alphard : (-0.00, 0.00)
# Gamma Hydrae : (57.83, -14.51)
# Zeta Hydrae : (-8.05, 14.60)
# Nu Hydrae : (-4.32, -2.96)
# Pi Hydrae : (69.69, -18.02)
# Epsilon Hydrae : (-10.21, 15.08)
# Xi Hydrae : (31.35, -23.20)
# Lambda Hydrae : (10.75, -3.70)
# Mu Hydrae : (-13.46, -1.34)
# Theta Hydrae : (-3.31, 10.97)
# Iota Hydrae : (3.06, 7.52)
# 30 Monocerotis : (-15.48, 4.75)
# Upsilon1 Hydrae : (5.97, -6.19)
# Delta Hydrae : (-12.49, 14.36)
# Beta Hydrae : (36.33, -25.25)
# Eta Hydrae : (-11.09, 12.06)
# 12 Hydrae : (-10.31, -4.89)
# Rho Hydrae : (-9.79, 14.50)
# 58 Hydrae : (80.67, -19.30)
# Sigma Hydrae : (-12.21, 12.00)
#
# Hydrus:
# Beta Hydri : (-0.00, -0.00)
# Alpha Hydri : (23.25, 15.68)
# Gamma Hydri : (50.37, 3.02)
# Delta Hydri : (29.00, 8.59)
# Epsilon Hydri : (33.46, 8.99)
# Zeta Hydri : (34.95, 9.64)
# Theta Hydri : (39.12, 5.35)
# BN Hyi : (40.44, -1.74)
# HD 10615 : (19.01, 16.46)
# HD 8810 : (14.83, 12.88)
# HD 1801 : (-1.07, -0.17)
# HD 21722 : (44.96, 7.92)
# HD 9896 : (17.37, 19.11)
# HD 11995 : (22.50, 16.39)
# HD 12477 : (23.48, 11.19)
# HD 10042 : (16.97, -1.25)
# HD 19940 : (40.51, 7.99)
# HD 21563 : (44.57, 7.63)
#
# Indus:
# Alpha Indi : (0.00, -0.00)
# Beta Indi : (4.31, -11.16)
# Theta Indi : (10.58, -6.16)
# Delta Indi : (20.09, -7.70)
# Eta Indi : (1.62, -4.63)
# Epsilon Indi : (21.45, -9.49)
# Zeta Indi : (2.98, 1.06)
# Iota Indi : (3.49, -4.32)
# Omicron Indi : (18.31, -22.34)
# HD 217831 : (36.83, -21.53)
# HD 212728 : (27.77, -20.20)
# HD 207229 : (18.11, -17.42)
# Kappa2 Indi : (22.07, -12.34)
# HD 202103 : (9.55, -5.97)
# HD 199623 : (5.70, -3.97)
# HD 212211 : (26.90, -23.14)
# HD 207964 : (19.41, -14.60)
# HD 206399 : (16.98, -23.72)
#
# Lacerta:
# Alpha Lacertae : (0.00, -0.00)
# 1 Lacertae : (-3.83, -12.53)
# 5 Lacertae : (-0.44, -2.58)
# Beta Lacertae : (-1.93, 1.95)
# HD 211073 : (-4.35, -10.57)
# 11 Lacertae : (2.31, -6.01)
# 6 Lacertae : (-0.20, -7.16)
# 2 Lacertae : (-2.56, -3.75)
# 4 Lacertae : (-1.69, -0.81)
# 9 Lacertae : (1.52, 1.26)
# 10 Lacertae : (2.00, -11.23)
# 15 Lacertae : (5.19, -6.97)
# V424 Lacertae : (6.29, -0.55)
# HD 209945 : (-6.31, -5.27)
# V416 Lac : (1.84, 6.51)
# 13 Lacertae : (3.20, -8.46)
# 12 Lacertae : (2.55, -10.06)
# EW Lacertae : (6.45, -1.60)
# HD 210715 : (-5.03, 0.54)
# HD 216174 : (4.62, 5.62)
#
# Monoceros:
# Alpha Monocerotis : (0.00, -0.00)
# Gamma Monocerotis : (-21.60, 3.28)
# Delta Monocerotis : (-7.34, 9.06)
# Zeta Monocerotis : (6.84, 6.57)
# Epsilon Monocerotis : (-19.37, 14.15)
# 13 Monocerotis : (-17.08, 16.88)
# 18 Monocerotis : (-13.34, 11.96)
# Beta Monocerotis : (-18.11, 2.52)
# S Monocerotis : (-15.07, 19.45)
# 28 Monocerotis : (5.00, 8.16)
# 17 Monocerotis : (-13.48, 17.59)
# 20 Monocerotis : (-7.75, 5.31)
# 3 Monocerotis : (-24.85, -1.05)
# 27 Monocerotis : (4.62, 5.87)
# 19 Monocerotis : (-9.58, 5.31)
# 2 Monocerotis : (-25.54, -0.01)
# HD 42690 : (-22.34, 3.00)
# 10 Monocerotis : (-18.32, 4.79)
# HD 49331 : (-13.40, 0.55)
# HD 46487 : (-16.90, 8.33)
#
# Lepus:
# Alpha Leporis : (0.00, 0.00)
# Beta Leporis : (-1.12, -2.94)
# Epsilon Leporis : (-6.81, -4.55)
# Zeta Leporis : (3.56, 3.00)
# Gamma Leporis : (2.94, -4.63)
# Eta Leporis : (5.92, 3.65)
# Delta Leporis : (4.65, -3.06)
# Lambda Leporis : (-3.29, 4.65)
# Kappa Leporis : (-4.87, 4.88)
# Iota Leporis : (-5.11, 5.95)
# Theta Leporis : (8.36, 2.89)
# HD 34968 : (-3.07, -3.42)
# HD 32309 : (-7.82, -2.23)
# 17 Leporis : (8.07, 1.34)
# HD 32436 : (-7.64, -8.45)
# HD 41312 : (7.64, -8.46)
# HD 34310 : (-4.33, -9.12)
# HD 35162 : (-2.74, -6.95)
# 8 Leporis : (-2.30, 3.89)
#
# Leo:
# Regulus : (0.00, 0.00)
# Denebola : (25.17, 2.60)
# Gamma Leonis : (2.90, 7.87)
# Delta Leonis : (16.44, 8.56)
# Epsilon Leonis : (-5.63, 11.81)
# Theta Leonis : (16.47, 3.46)
# Zeta Leonis : (2.08, 11.45)
# Eta Leonis : (-0.26, 4.80)
# Omicron Leonis : (-6.80, -2.07)
# Omicron Leonis : (-6.80, -2.07)
# Omicron Leonis : (-6.80, -2.07)
# Gamma Leonis : (2.90, 7.87)
# Rho Leonis : (6.11, -2.66)
# Mu Leonis : (4.16, 12.55)
# Iota Leonis : (18.89, -1.44)
# Sigma Leonis : (18.19, -5.94)
# 54 Leonis : (11.81, 12.78)
# Upsilon Leonis : (22.15, -12.79)
# Lambda Leonis : (-9.16, 11.00)
# 31 Leonis : (-0.11, -1.97)
#
# Lupus:
# Alpha Lupi : (0.00, 0.00)
# Beta Lupi : (4.15, 4.25)
# Gamma Lupi : (13.31, 6.22)
# Delta Lupi : (9.86, 6.74)
# Epsilon Lupi : (10.19, 2.70)
# Zeta Lupi : (7.59, -4.71)
# Eta Lupi : (19.55, 8.99)
# Iota Lupi : (-5.63, 1.33)
# Phi1 Lupi : (9.97, 11.13)
# Kappa1 Lupi : (7.50, -1.35)
# Pi Lupi : (5.80, 0.34)
# Chi Lupi : (17.26, 13.76)
# Rho Lupi : (-1.01, -2.04)
# Lambda Lupi : (6.73, 2.11)
# Theta Lupi : (21.17, 10.59)
# Mu Lupi : (14.69, 9.45)
# Omicron Lupi : (2.43, 3.81)
# Tau2 Lupi : (-3.93, 2.01)
# Omega Lupi : (14.03, 4.82)
# 2 Lupi : (8.98, 17.24)
#
# Lynx:
# Alpha Lyncis : (0.00, -0.00)
# 38 Lyncis : (-0.55, 2.41)
# 10 Ursae Majoris : (-5.10, 7.39)
# 31 Lyncis : (-14.55, 8.80)
# 15 Lyncis : (-35.94, 24.03)
# 2 Lyncis : (-45.35, 24.62)
# HD 77912 : (-3.63, 4.06)
# 21 Lyncis : (-28.58, 14.82)
# 27 Lyncis : (-18.15, 17.11)
# HD 82741 : (3.51, 5.23)
# 12 Lyncis : (-38.70, 25.05)
# 16 Lyncis : (-35.86, 10.70)
# 24 Lyncis : (-24.51, 24.32)
# 1 Lyncis : (-45.78, 27.12)
# HD 56169 : (-30.63, 15.07)
# 35 Lyncis : (-7.27, 9.33)
# DU Lyncis : (-23.60, 3.12)
# 18 Lyncis : (-31.28, 25.24)
# 5 Lyncis : (-43.56, 24.02)
# 42 Lyncis : (4.33, 5.85)
#
# Lyra:
# Vega : (0.00, -0.00)
# Gamma Lyrae : (5.51, -6.09)
# Beta Lyrae : (3.29, -5.42)
# R Lyrae : (4.60, 5.16)
# Delta2 Lyrae : (4.40, -1.89)
# Kappa Lyrae : (-4.26, -2.72)
# Zeta1 Lyrae : (1.96, -1.18)
# Theta Lyrae : (9.86, -0.65)
# Eta Lyrae : (9.21, 0.36)
# Epsilon2 Lyrae : (1.86, 0.83)
# Epsilon1 Lyrae : (1.85, 0.89)
# HD 173780 : (2.29, -12.12)
# Lambda Lyrae : (5.77, -6.64)
# 16 Lyrae : (6.13, 8.15)
# Mu Lyrae : (9.90, -8.13)
# HD 176051 : (5.03, -5.88)
# 17 Lyrae : (7.63, -6.28)
# Iota Lyrae : (7.60, -2.68)
# HD 176527 : (5.71, -12.55)
#
# Antlia:
# Alpha Antliae : (-0.00, 0.00)
# Epsilon Antliae : (-14.48, -4.88)
# Iota Antliae : (7.39, -6.07)
# Theta Antliae : (-10.74, 3.30)
# Eta Antliae : (-7.07, -4.82)
# HD 90132 : (-0.92, -6.94)
# HD 96146 : (9.44, -4.74)
# HD 82205 : (-14.31, 4.48)
# U Antliae : (2.01, -8.49)
# HR 4049 : (-2.26, 2.08)
# Delta Antliae : (0.61, 0.46)
# HD 93905 : (5.70, -2.99)
# HR 3833 : (-12.50, -1.11)
# HD 92845 : (3.89, -1.65)
# HR 3830 : (-12.54, 5.77)
# Zeta1 Antliae : (-14.10, -0.82)
# HD 86267 : (-7.64, -2.35)
# HD 82514 : (-13.90, -4.65)
# Zeta2 Antliae : (-13.91, -0.80)
# HD 88809 : (-3.35, -9.28)
#
# Microscopium:
# Gamma Microscopii : (0.00, -0.00)
# Epsilon Microscopii : (4.16, 0.09)
# Theta1 Microscopii : (4.87, -8.55)
# Alpha Microscopii : (-2.83, -1.52)
# Iota Microscopii : (-3.20, -11.73)
# 2 Piscis Austrini : (1.28, -0.08)
# HD 201772 : (2.94, -7.17)
# Zeta Microscopii : (0.42, -6.37)
# HD 198716 : (-1.90, -7.55)
# 3 Piscis Austrini : (3.00, 4.64)
# HD 196737 : (-5.24, -1.17)
# HD 197630 : (-3.74, -6.94)
# HD 204018 : (6.44, -10.29)
# HD 198357 : (-2.57, -5.66)
# Eta Microscopii : (1.29, -9.13)
# HD 203949 : (6.28, -5.57)
# Delta Microscopii : (1.18, 2.13)
# HD 196917 : (-4.97, 0.66)
# Theta2 Microscopii : (5.78, -8.75)
#
# Musca:
# Alpha Muscae : (-0.00, 0.00)
# Beta Muscae : (2.27, 1.03)
# Delta Muscae : (6.27, -2.41)
# Lambda Muscae : (-12.90, 2.41)
# Gamma Muscae : (-1.18, -3.00)
# Epsilon Muscae : (-4.91, 1.17)
# Mu Muscae : (-18.95, -3.43)
# Eta Muscae : (9.51, 1.24)
# HD 115211 : (10.00, 2.35)
# HD 103079 : (-11.34, 3.93)
# HD 102839 : (-11.81, -1.09)
# GT Muscae : (-14.43, 3.74)
# Iota1 Muscae : (11.98, -5.75)
# HD 99104 : (-18.46, 4.18)
# Zeta2 Muscae : (-3.77, 1.61)
# HD 104878 : (-8.14, 0.81)
# Theta Muscae : (7.73, 3.83)
# HD 99264 : (-18.25, -3.12)
# HD 111315 : (3.14, -2.85)
#
# Octans:
# Beta Octantis : (0.00, -0.00)
# Delta Octantis : (-124.78, -2.29)
# Theta Octantis : (-341.11, 4.32)
# Epsilon Octantis : (-6.50, 0.94)
# Gamma1 Octantis : (16.52, -0.64)
# Alpha Octantis : (-25.33, 4.36)
# Lambda Octantis : (-13.78, -1.34)
# Gamma3 Octantis : (-339.00, -0.84)
# Chi Octantis : (-57.81, -6.22)
# Xi Octantis : (1.09, 1.26)
# Zeta Octantis : (-207.34, -4.28)
# Iota Octantis : (-147.76, -3.74)
# Sigma Octantis : (-24.31, -7.57)
# Phi Octantis : (-65.61, 6.34)
# Psi Octantis : (-7.05, 3.87)
# Tau Octantis : (10.51, -6.10)
# Kappa Octantis : (-136.28, -4.40)
# Rho Octantis : (-105.69, -3.08)
# Pi1 Octantis : (-116.05, -1.85)
#
# Apus:
# Alpha Apodis : (-0.00, 0.00)
# Gamma Apodis : (26.39, 0.15)
# Beta Apodis : (28.80, 1.53)
# Delta1 Apodis : (23.12, 0.35)
# Zeta Apodis : (38.53, 11.27)
# Eta Apodis : (-7.41, -1.96)
# Epsilon Apodis : (-6.37, -1.06)
# Delta2 Apodis : (23.14, 0.38)
# R Apodis : (2.50, 2.38)
# Iota Apodis : (38.55, 8.92)
# HR 6135 : (26.61, 8.06)
# HD 130458 : (1.34, 5.85)
# Theta Apodis : (-10.64, 2.25)
# HD 143346 : (19.51, 6.64)
# NO Apodis : (40.89, -1.81)
# HD 164712 : (50.85, 3.15)
# HD 165259 : (51.17, 5.37)
# HD 131425 : (3.08, 1.88)
#
# Ophiucus:
# Alpha Ophiuchi : (0.00, 0.00)
# Eta Ophiuchi : (-6.14, -28.28)
# Zeta Ophiuchi : (-14.44, -23.13)
# Delta Ophiuchi : (-20.14, -16.25)
# Beta Ophiuchi : (2.14, -7.99)
# Kappa Ophiuchi : (-9.31, -3.18)
# Epsilon Ophiuchi : (-19.15, -17.25)
# Theta Ophiuchi : (-3.23, -37.56)
# Nu Ophiuchi : (-8.84, -42.65)
# 72 Ophiuchi : (8.11, -3.00)
# Gamma Ophiuchi : (3.24, -9.85)
# Lambda Ophiuchi : (-16.00, -10.58)
# 67 Ophiuchi : (6.43, -9.63)
# 70 Ophiuchi : (7.63, -10.06)
# 44 Ophiuchi : (-2.14, -36.74)
# Chi Ophiuchi : (-16.97, -31.02)
# 45 Ophiuchi : (-1.89, -42.43)
# Phi Ophiuchi : (-15.95, -29.17)
# 36 Ophiuchi : (-4.89, -39.16)
# Sigma Ophiuchi : (-2.10, -8.42)
#
# Orion:
# Rigel : (0.00, -0.00)
# Betelgeuse : (10.16, 15.61)
# Bellatrix : (2.65, 14.55)
# Alnilam : (5.42, 7.00)
# Alnitak : (6.56, 6.26)
# Saiph : (8.31, -1.47)
# Mintaka : (4.37, 7.90)
# Iota Orionis : (5.23, 2.29)
# Eta Orionis : (2.49, 5.80)
# Meissa : (5.15, 18.14)
# Tau Orionis : (0.77, 1.36)
# Pi4 Orionis : (-5.83, 13.81)
# Alnitak : (6.56, 6.26)
# Pi5 Orionis : (-5.07, 10.64)
# Sigma Orionis : (6.06, 5.60)
# Omicron2 Orionis : (-4.54, 21.72)
# Mu Orionis : (5.20, 2.93)
# 29 Orionis : (2.36, 0.39)
#
# Pavo:
# Alpha Pavonis : (0.00, 0.00)
# Beta Pavonis : (4.83, -9.47)
# Delta Pavonis : (-4.23, -9.45)
# Eta Pavonis : (-39.98, -7.99)
# Epsilon Pavonis : (-6.26, -16.18)
# Zeta Pavonis : (-25.65, -14.69)
# Gamma Pavonis : (15.20, -8.63)
# Lambda Pavonis : (-23.36, -5.45)
# Pi Pavonis : (-34.26, -6.93)
# Xi Pavonis : (-30.60, -4.76)
# Kappa Pavonis : (-22.17, -10.50)
# Nu Pavonis : (-5.97, -2.64)
# Phi1 Pavonis : (2.49, -3.85)
# HD 172555 : (-25.05, -8.14)
# Rho Pavonis : (2.99, -4.79)
# NU Pavonis : (-5.97, -2.64)
# Omicron Pavonis : (11.93, -13.39)
# Phi2 Pavonis : (3.60, -3.81)
# Omega Pavonis : (-21.76, -3.47)
# Upsilon Pavonis : (4.08, -10.03)
#
# Pegasus:
# Epsilon Pegasi : (-0.00, 0.00)
# Beta Pegasi : (19.89, 18.21)
# Alpha Pegasi : (20.14, 5.33)
# Gamma Pegasi : (-322.74, 5.31)
# Eta Pegasi : (14.70, 20.35)
# Zeta Pegasi : (14.32, 0.96)
# Mu Pegasi : (20.43, 18.29)
# Theta Pegasi : (6.50, -3.68)
# Iota Pegasi : (5.70, 15.47)
# Lambda Pegasi : (15.58, 13.69)
# 1 Pegasi : (-5.53, 9.93)
# Kappa Pegasi : (0.11, 15.77)
# Xi Pegasi : (15.62, 2.30)
# Pi Pegasi : (6.45, 23.30)
# 9 Pegasi : (0.08, 7.48)
# Upsilon Pegasi : (25.29, 13.53)
# 2 Pegasi : (-3.56, 13.76)
# 55 Pegasi : (20.70, -0.47)
# 70 Pegasi : (26.24, 2.89)
# Tau Pegasi : (24.11, 13.87)
#
# Pictor:
# Alpha Pictoris : (-0.00, 0.00)
# Beta Pictoris : (-15.23, 10.87)
# Gamma Pictoris : (-14.59, 5.77)
# Delta Pictoris : (-9.48, 6.97)
# HD 42540 : (-10.29, -0.21)
# Eta2 Pictoris : (-25.81, 12.36)
# HD 39640 : (-14.33, 9.83)
# HD 46355 : (-4.68, 5.09)
# HD 40292 : (-13.34, 9.31)
# Lambda Pictoris : (-31.36, 11.46)
# HD 38871 : (-15.44, 15.34)
# Eta1 Pictoris : (-26.35, 12.79)
# Zeta Pictoris : (-22.21, 11.34)
# HD 36553 : (-19.51, 14.86)
# Iota Pictoris : (-29.32, 8.49)
# HD 41214 : (-11.85, 10.73)
# HD 45557 : (-5.99, 1.66)
# HD 40733 : (-12.39, 17.91)
#
# Perseus:
# Alpha Persei : (0.00, -0.00)
# Algol : (-4.04, -8.91)
# Zeta Persei : (7.45, -17.98)
# Epsilon Persei : (8.38, -9.85)
# Gamma Persei : (-4.88, 3.65)
# Gamma Persei : (-4.88, 3.65)
# Delta Persei : (4.65, -2.07)
# Rho Persei : (-4.79, -11.02)
# Eta Persei : (-8.41, 6.03)
# Nu Persei : (13.85, 0.26)
# Kappa Persei : (-3.71, -5.00)
# Omicron Persei : (5.00, -17.57)
# Tau Persei : (-7.52, 2.90)
# 48 Persei : (11.09, -2.15)
# Xi Persei : (8.66, -14.07)
# Tau Persei : (-7.52, 2.90)
# Phi Persei : (-25.16, 0.83)
# Iota Persei : (-3.81, -0.25)
# Theta Persei : (-10.03, -0.63)
# Mu Persei : (9.61, 2.34)
#
# Equuleus:
# Alpha Equulei : (-0.00, -0.00)
# Delta Equulei : (-0.34, 4.76)
# Gamma Equulei : (-1.37, 4.88)
# Beta Equulei : (1.76, 1.56)
# Epsilon Equulei : (-4.19, -0.95)
# 9 Equulei : (1.31, 2.11)
# 4 Equulei : (-2.60, 0.71)
# HD 202951 : (0.76, 5.96)
# HD 199942 : (-3.94, 2.27)
# 6 Equulei : (-1.33, 4.80)
# HD 201298 : (-1.84, 1.74)
# HD 203842 : (2.14, 4.93)
# HD 200661 : (-2.79, -2.31)
# HD 201507 : (-1.47, -2.30)
# HD 200964 : (-2.29, -1.44)
# HD 202908 : (0.69, 6.32)
# Gliese 818 : (-2.63, 1.82)
# HD 203473 : (1.62, -0.22)
#
# Canis Minor:
# Procyon : (-0.00, -0.00)
# Beta Canis Minoris : (-3.04, 3.06)
# Gamma Canis Minoris : (-2.79, 3.70)
# HD 66141 : (5.74, -2.89)
# 6 Canis Minoris : (-2.38, 6.78)
# Epsilon Canis Minoris : (-3.42, 4.05)
# Zeta Canis Minoris : (3.09, -3.46)
# Eta Canis Minoris : (-2.82, 1.72)
# Delta1 Canis Minoris : (-1.81, -3.31)
# 11 Canis Minoris : (1.74, 5.54)
# 14 Canis Minoris : (4.76, -3.00)
# HD 55751 : (-6.25, -2.11)
# 1 Canis Minoris : (-3.59, 6.44)
# Delta2 Canis Minoris : (-1.53, -1.93)
# HD 65900 : (5.48, -0.35)
# HD 55730 : (-6.19, 6.89)
# HD 54079 : (-7.87, 2.25)
# HD 56031 : (-5.92, 2.75)
# Delta3 Canis Minoris : (-1.26, -1.85)
# HD 64685 : (4.05, 3.64)
#
# Leo Minor:
# 46 Leonis Minoris : (-0.00, -0.00)
# Beta Leonis Minoris : (-6.36, 2.49)
# 21 Leonis Minoris : (-11.47, 1.03)
# 10 Leonis Minoris : (-19.77, 2.18)
# 37 Leonis Minoris : (-3.65, -2.24)
# 30 Leonis Minoris : (-6.85, -0.42)
# 41 Leonis Minoris : (-2.48, -11.03)
# 19 Leonis Minoris : (-13.91, 6.84)
# 42 Leonis Minoris : (-1.86, -3.53)
# 20 Leonis Minoris : (-13.08, -2.29)
# 11 Leonis Minoris : (-19.42, 1.60)
# 8 Leonis Minoris : (-20.44, 0.89)
# 23 Leonis Minoris : (-9.27, -4.90)
# 40 Leonis Minoris : (-2.57, -7.89)
# 28 Leonis Minoris : (-7.29, -0.50)
# 34 Leonis Minoris : (-4.95, 0.77)
# 32 Leonis Minoris : (-5.80, 4.71)
# 38 Leonis Minoris : (-3.55, 3.70)
# HD 88231 : (-10.53, 3.19)
# 7 Leonis Minoris : (-20.65, -0.56)
#
# Vulpecula:
# Alpha Vulpeculae : (-0.00, 0.00)
# 23 Vulpeculae : (11.76, 3.15)
# 31 Vulpeculae : (20.85, 2.43)
# 13 Vulpeculae : (6.19, -0.59)
# 15 Vulpeculae : (8.10, 3.09)
# 1 Vulpeculae : (-3.13, -3.27)
# HR 7739 : (11.64, 0.93)
# 29 Vulpeculae : (17.45, -3.46)
# 12 Vulpeculae : (5.59, -2.05)
# 30 Vulpeculae : (19.04, 0.61)
# 9 Vulpeculae : (1.47, -4.89)
# 32 Vulpeculae : (21.46, 3.39)
# 28 Vulpeculae : (17.45, -0.55)
# 17 Vulpeculae : (9.54, -1.05)
# 4 Vulpeculae : (-0.81, -4.87)
# 22 Vulpeculae : (11.70, -1.16)
# 3 Vulpeculae : (-1.47, 1.60)
# 21 Vulpeculae : (11.38, 4.03)
# 16 Vulpeculae : (8.33, 0.27)
# 24 Vulpeculae : (12.02, 0.01)
#
# Ursa Minor:
# Polaris : (0.00, 0.00)
# Beta Ursae Minoris : (184.73, -15.11)
# Gamma Ursae Minoris : (192.23, -17.43)
# Epsilon Ursae Minoris : (213.54, -7.23)
# 5 Ursae Minoris : (178.93, -13.57)
# Zeta Ursae Minoris : (198.06, -11.47)
# Delta Ursae Minoris : (225.10, -2.68)
# RR Ursae Minoris : (186.45, -23.33)
# 4 Ursae Minoris : (174.26, -11.72)
# Eta Ursae Minoris : (206.43, -13.51)
# Theta Ursae Minoris : (194.90, -11.91)
# 11 Ursae Minoris : (191.32, -17.44)
# HD 136064 : (190.71, -21.92)
# HD 124730 : (175.07, -19.83)
# 19 Ursae Minoris : (204.76, -13.39)
# HD 118904 : (166.35, -18.02)
# HD 149681 : (208.48, -10.30)
# HD 133002 : (184.64, -6.75)
# HD 140227 : (196.46, -19.98)
# HD 145622 : (202.93, -12.47)
#
# Phoenix:
# Alpha Phoenicis : (0.00, 0.00)
# Beta Phoenicis : (9.95, -4.41)
# Gamma Phoenicis : (15.52, -1.01)
# Epsilon Phoenicis : (-4.22, -3.44)
# Kappa Phoenicis : (-0.02, -1.37)
# Delta Phoenicis : (16.24, -6.77)
# Zeta Phoenicis : (10.53, -12.94)
# Eta Phoenicis : (4.27, -15.16)
# Psi Phoenicis : (21.84, -4.00)
# Iota Phoenicis : (347.20, -0.31)
# HD 222095 : (347.89, -3.19)
# Lambda1 Phoenicis : (1.28, -6.50)
# HD 12055 : (22.72, -5.08)
# Phi Phoenicis : (22.02, -0.19)
# Chi Phoenicis : (23.86, -2.41)
# Rho Phoenicis : (6.10, -8.68)
# HD 6245 : (9.13, -4.09)
# HD 2490 : (0.54, 2.39)
#
# Pisces:
# Eta Piscium : (0.00, 0.00)
# Gamma Piscium : (326.42, -12.06)
# Omega Piscium : (336.96, -8.48)
# Iota Piscium : (332.12, -9.72)
# Omicron Piscium : (3.48, -6.19)
# Epsilon Piscium : (-7.13, -7.46)
# Theta Piscium : (329.12, -8.97)
# Alpha Piscium : (7.64, -12.58)
# 30 Piscium : (-22.38, -21.36)
# Delta Piscium : (-10.70, -7.76)
# Beta Piscium : (323.10, -11.53)
# Lambda Piscium : (332.64, -13.57)
# Tau Piscium : (-4.95, 14.74)
# 33 Piscium : (-21.54, -21.05)
# Xi Piscium : (5.52, -12.16)
# Chi Piscium : (-5.01, 5.69)
# Phi Piscium : (-4.43, 9.24)
# Upsilon Piscium : (-3.00, 11.92)
#
# Pisces Austrinus:
# Fomalhaut : (0.00, -0.00)
# Epsilon Piscis Austrini : (-4.25, 2.58)
# Delta Piscis Austrini : (-0.42, -2.92)
# Beta Piscis Austrini : (-6.53, -2.72)
# Iota Piscis Austrini : (-18.17, -3.40)
# Gamma Piscis Austrini : (-1.28, -3.25)
# Tau Piscis Austrini : (-11.87, -2.93)
# Upsilon Piscis Austrini : (-12.30, -4.42)
# Theta Piscis Austrini : (-17.48, -1.28)
# Pi Piscis Austrini : (1.46, -5.13)
# HD 210271 : (-11.93, -4.39)
# Eta Piscis Austrini : (-14.20, 1.17)
# Lambda Piscis Austrini : (-10.83, 1.86)
# HD 217484 : (0.92, 0.77)
# HD 210848 : (-10.97, 4.44)
# HD 217303 : (0.61, 4.46)
# HD 214122 : (-5.26, -2.04)
# HD 214690 : (-4.32, -1.04)
# HD 213135 : (-6.97, 2.51)
#
# Volans:
# Beta Volantis : (0.00, 0.00)
# Zeta Volantis : (-10.97, -6.47)
# Delta Volantis : (-17.22, -1.82)
# Alpha Volantis : (9.18, -0.26)
# Epsilon Volantis : (-4.45, -2.48)
# HD 70514 : (-1.85, 0.52)
# HD 53501 : (-21.47, -1.78)
# Theta Volantis : (3.34, -4.25)
# Eta Volantis : (-0.91, -7.26)
# HD 76143 : (6.22, -0.66)
# Iota Volantis : (-23.57, -4.83)
# HD 72337 : (0.39, -3.96)
# HD 64484 : (-9.01, -0.06)
# HD 77887 : (8.86, -2.55)
# HD 71863 : (0.03, 1.54)
# HD 75171 : (4.69, 0.31)
#
# Puppis:
# Zeta Puppis : (-0.00, -0.00)
# Pi Puppis : (-11.61, 2.91)
# Rho Puppis : (0.99, 15.70)
# Tau Puppis : (-18.42, -10.61)
# Nu Puppis : (-22.70, -3.90)
# Sigma Puppis : (-8.59, -3.30)
# Xi Puppis : (-3.58, 15.14)
# C Puppis : (-14.89, -2.33)
# HD 64440 : (-2.85, -0.57)
# 3 Puppis : (-4.95, 11.05)
# HD 63922 : (-3.59, -6.37)
# 11 Puppis : (-1.69, 17.12)
# HD 64760 : (-2.57, -8.10)
# Omicron Puppis : (-3.88, 14.07)
# 16 Puppis : (1.36, 20.76)
# HD 69142 : (2.61, -0.34)
# NS Puppis : (1.94, 0.38)
# HD 70060 : (3.74, 3.34)
# HD 60532 : (-7.39, 17.71)
#
# Reticulum:
# Alpha Reticuli : (-0.00, -0.00)
# Beta Reticuli : (-7.56, -2.33)
# Epsilon Reticuli : (0.51, 3.17)
# Gamma Reticuli : (-3.39, 0.31)
# Delta Reticuli : (-3.92, 1.07)
# Kappa Reticuli : (-11.27, -0.46)
# Iota Reticuli : (-3.28, 1.39)
# Eta Reticuli : (1.86, -0.91)
# HD 27304 : (0.09, 0.28)
# HD 28732 : (3.33, -0.05)
# HD 29399 : (4.78, -0.35)
# HD 22252 : (-10.89, -4.02)
# Theta Reticuli : (0.81, -0.78)
# HD 28413 : (2.66, 1.24)
# HD 20888 : (-14.11, -4.45)
# HD 25346 : (-3.93, 5.37)
# HD 25170 : (-4.59, -0.99)
# HD 23697 : (-7.47, 8.20)
#
# Sagittarius:
# Epsilon Sagittarii : (0.00, -0.00)
# Sigma Sagittarii : (7.78, 8.09)
# Zeta Sagittarii : (9.61, 4.50)
# Delta Sagittarii : (-0.79, 4.56)
# Lambda Sagittarii : (0.95, 8.96)
# Pi Sagittarii : (11.40, 13.36)
# Gamma2 Sagittarii : (-4.59, 3.96)
# Eta Sagittarii : (-1.63, -2.38)
# Phi Sagittarii : (5.37, 7.39)
# Tau Sagittarii : (10.70, 6.71)
# Xi2 Sagittarii : (8.39, 13.28)
# Omicron Sagittarii : (10.13, 12.64)
# Mu Sagittarii : (5.05, 6.26)
# Rho1 Sagittarii : (14.38, 16.54)
# Beta1 Sagittarii : (14.62, -10.07)
# Alpha Sagittarii : (14.93, -6.23)
# Iota Sagittarii : (22.78, -7.48)
# Beta2 Sagittarii : (14.76, -10.42)
# Theta1 Sagittarii : (23.89, -0.89)
# 62 Sagittarii : (24.62, 6.67)
#
# Scorpius:
# Antares : (0.00, -0.00)
# Lambda Scorpii : (16.05, -10.67)
# Theta Scorpii : (16.98, -16.57)
# Delta Scorpii : (-7.27, 3.81)
# Epsilon Scorpii : (5.19, -7.86)
# Kappa Scorpii : (18.27, -12.60)
# Beta1 Scorpii : (-5.99, 6.63)
# Upsilon Scorpii : (15.34, -10.86)
# Tau Scorpii : (1.62, -1.78)
# Pi Scorpii : (-7.64, 0.32)
# Sigma Scorpii : (-2.05, 0.84)
# Iota1 Scorpii : (19.55, -13.69)
# G Scorpii : (20.11, -10.61)
# Eta Scorpii : (10.69, -16.81)
# Zeta2 Scorpii : (6.30, -15.93)
# Rho Scorpii : (-8.13, -2.78)
# Omega1 Scorpii : (-5.65, 5.76)
# Nu Scorpii : (17.92, -17.87)
#
# Scutum:
# Alpha Scuti : (0.00, 0.00)
# Beta Scuti : (2.99, 3.50)
# Zeta Scuti : (-2.89, -0.69)
# Gamma Scuti : (-1.50, -6.32)
# Delta Scuti : (1.77, -0.81)
# Eta Scuti : (5.47, 2.40)
# Epsilon Scuti : (2.08, -0.03)
# HD 175156 : (4.88, -7.36)
# HD 171391 : (-0.04, -2.73)
# R Scuti : (3.07, 2.54)
# V450 Sct : (-0.62, -6.62)
# HD 173638 : (2.88, -1.88)
# HD 169033 : (-3.00, -3.77)
# HD 171130 : (-0.39, -6.61)
# HD 170740 : (-0.94, -2.55)
# HD 172348 : (1.20, 0.45)
# HD 174464 : (3.94, -1.53)
# HD 174208 : (3.62, 2.33)
# V432 Sct : (-1.36, -6.34)
# HD 172831 : (1.85, 1.17)
#
# Serpens:
# Alpha Serpentis : (-0.00, 0.00)
# Eta Serpentis : (39.26, -9.32)
# Mu Serpentis : (32.90, -20.45)
# Xi Serpentis : (28.33, -21.82)
# Beta Serpentis : (0.48, 9.00)
# Epsilon Serpentis : (1.63, -1.95)
# Gamma Serpentis : (3.04, 9.24)
# Kappa Serpentis : (1.11, 11.72)
# Delta Serpentis : (-2.37, 4.11)
# Omicron Serpentis : (29.28, -19.30)
# Nu Serpentis : (31.08, -19.47)
# Lambda Serpentis : (0.54, 0.93)
# Iota Serpentis : (-0.68, 13.24)
# Zeta Serpentis : (34.05, -10.12)
# Theta1 Serpentis : (47.98, -2.22)
# Rho Serpentis : (1.75, 14.55)
# Pi Serpentis : (4.50, 16.38)
# Sigma Serpentis : (9.45, -5.40)
# Theta2 Serpentis : (47.99, -2.22)
# 5 Serpentis : (-6.24, -4.66)
#
# Sextans:
# Alpha Sextantis : (0.00, 0.00)
# Gamma Sextantis : (-3.85, -7.73)
# Beta Sextantis : (5.59, -0.27)
# Delta Sextantis : (5.39, -2.37)
# Epsilon Sextantis : (2.43, -7.70)
# HD 90362 : (4.45, -6.69)
# 18 Sextantis : (0.75, -8.05)
# HD 84607 : (-5.38, 2.16)
# 19 Sextantis : (1.22, 4.99)
# 35 Sextantis : (8.86, 5.12)
# 41 Sex : (10.60, -8.53)
# HD 93833 : (10.45, -9.48)
# HD 85709 : (-3.55, 6.33)
# 17 Sex : (0.55, -8.04)
# HD 93655 : (10.19, -1.59)
# HD 94014 : (10.79, -2.72)
# 25 Sex : (3.88, -3.70)
# 6 Sex : (-4.17, -3.87)
# 7 Sex : (-3.93, 2.83)
# HD 90763 : (5.20, -3.37)
#
# Mensa:
# Alpha Mensae : (0.00, -0.00)
# Gamma Mensae : (-9.59, -1.59)
# Beta Mensae : (-16.88, 3.44)
# Theta Mensae : (11.58, -4.67)
# Kappa Mensae : (-4.99, -4.61)
# Eta Mensae : (-18.76, -0.18)
# Epsilon Mensae : (18.85, -4.34)
# Zeta Mensae : (7.45, -6.06)
# Pi Mensae : (-8.27, -5.72)
# Delta Mensae : (-28.06, -5.46)
# HD 22676 : (-40.06, -3.60)
# WX Men : (-8.87, 1.01)
# Xi Mensae : (-17.85, -7.72)
# Iota Mensae : (-8.66, -4.07)
# HD 30479 : (-22.97, -2.90)
# TZ Mensae : (-10.00, -10.03)
# HD 33875 : (-16.02, 1.72)
# HD 31975 : (-19.29, 2.35)
#
# Taurus:
# Aldebaran : (0.00, 0.00)
# Beta Tauri : (12.59, 12.10)
# Alcyone : (-12.11, 7.60)
# Zeta Tauri : (15.43, 4.63)
# Lambda Tauri : (-8.81, -4.02)
# Epsilon Tauri : (-1.83, 2.67)
# Omicron Tauri : (-17.78, -7.48)
# Atlas : (-11.69, 7.54)
# Gamma Tauri : (-4.03, -0.88)
# Electra : (-12.76, 7.60)
# Xi Tauri : (-17.19, -6.78)
# Delta Tauri : (-3.25, 1.03)
# Maia : (-12.52, 7.86)
# Nu Tauri : (-12.78, 7.71)
# 5 Tauri : (-16.26, -3.57)
# Merope : (-12.40, 7.44)
# 88 Tauri : (-0.07, -6.35)
#
# Telescopium:
# Alpha Telescopii : (0.00, 0.00)
# Zeta Telescopii : (0.47, -3.10)
# Epsilon Telescopii : (-3.93, 0.01)
# Lambda Telescopii : (7.88, -6.97)
# Iota Telescopii : (17.06, -2.13)
# Delta1 Telescopii : (1.20, 0.05)
# Xi Telescopii : (25.11, -6.91)
# Eta Telescopii : (13.97, -8.46)
# Delta2 Telescopii : (1.27, 0.21)
# Rho Telescopii : (9.84, -6.37)
# Kappa Telescopii : (6.43, -6.14)
# Nu Telescopii : (-3.49, -9.17)
# QV Telescopii : (-2.46, -10.05)
# HD 179886 : (12.35, 0.50)
# HD 169405 : (-0.01, -2.15)
# HD 174387 : (6.37, -0.63)
# PW Telescopii : (16.60, 0.70)
# HD 191829 : (26.84, -6.48)
# HD 170069 : (0.74, -1.25)
# HD 182509 : (15.21, -8.36)
#
# Tucana:
# Alpha Tucanae : (-0.00, -0.00)
# Gamma Tucanae : (14.73, 2.02)
# Zeta Tucanae : (-329.61, -4.62)
# Kappa Tucanae : (-315.69, -8.62)
# Epsilon Tucanae : (25.35, -5.32)
# Delta Tucanae : (2.20, -4.71)
# Nu Tucanae : (3.62, -1.72)
# Eta Tucanae : (24.77, -4.04)
# HD 212330 : (1.60, 2.46)
# Iota Tucanae : (-317.80, -1.52)
# Rho Tucanae : (-324.01, -5.21)
# Lambda Tucanae : (-320.88, -9.27)
# Pi Tucanae : (-329.47, -9.37)
# HD 225253 : (-333.46, -11.18)
# HD 220572 : (16.70, 3.41)
# HD 220790 : (17.18, 1.78)
# HD 219482 : (14.61, -1.74)
#
# Triangulum:
# Beta Trianguli : (-0.00, -0.00)
# Alpha Trianguli : (-4.12, -5.41)
# Gamma Trianguli : (1.94, -1.14)
# Delta Trianguli : (1.87, -0.76)
# Iota Trianguli : (0.70, -4.68)
# 14 Trianguli : (5.64, 1.16)
# 7 Trianguli : (1.59, -1.63)
# 10 Trianguli : (2.35, -6.34)
# 12 Trianguli : (4.65, -5.32)
# 15 Trianguli : (6.56, -0.30)
# R Trianguli : (6.87, -0.72)
# Epsilon Trianguli : (-1.65, -1.70)
# 11 Trianguli : (4.48, -3.19)
# HD 10390 : (-6.88, 0.26)
# HD 11007 : (-5.22, -2.30)
# HD 11928 : (-2.96, -7.18)
# HD 15755 : (5.83, -0.44)
# 13 Trianguli : (4.81, -5.06)
# HD 10348 : (-6.98, -4.94)
# HD 16187 : (6.79, -3.38)
#
# Triangulum Australe:
# Alpha Trianguli Australis : (-0.00, -0.00)
# Beta Trianguli Australis : (-13.38, 5.60)
# Gamma Trianguli Australis : (-22.44, 0.35)
# Delta Trianguli Australis : (-8.31, 5.34)
# Epsilon Trianguli Australis : (-17.99, 2.71)
# Zeta Trianguli Australis : (-5.05, -1.06)
# LP TrA : (-0.50, 1.92)
# Kappa Trianguli Australis : (-13.30, 0.42)
# HD 148291 : (-4.46, 7.39)
# Iota Trianguli Australis : (-5.18, 4.97)
# Theta Trianguli Australis : (-3.23, 3.53)
# HD 140483 : (-15.20, 3.59)
# LX TrA : (-20.28, 4.50)
# HD 142514 : (-12.43, 3.99)
# X Trianguli Australis : (-23.59, -1.05)
# HD 133683 : (-24.80, 1.94)
# HD 142139 : (-13.15, 8.55)
# MX TrA : (2.72, -0.24)
# HD 136672 : (-20.61, 0.72)
#
# Aquarius:
# Beta Aquarii : (-0.00, 0.00)
# Alpha Aquarii : (8.56, 5.25)
# Delta Aquarii : (20.77, -10.25)
# Zeta Aquarii : (14.32, 5.55)
# 88 Aquarii : (24.47, -15.60)
# Lambda Aquarii : (20.26, -2.01)
# Epsilon Aquarii : (-10.97, -3.92)
# Gamma Aquarii : (12.52, 4.18)
# 98 Aquarii : (27.85, -14.53)
# Eta Aquarii : (15.95, 5.45)
# Tau2 Aquarii : (19.51, -8.02)
# Theta Aquarii : (11.32, -2.21)
# Phi Aquarii : (25.69, -0.48)
# Psi1 Aquarii : (26.08, -3.52)
# Iota Aquarii : (8.72, -8.30)
# 99 Aquarii : (28.62, -15.07)
# Psi2 Aquarii : (26.59, -3.61)
# Zeta Aquarii : (14.32, 5.55)
# 3 Aquarii : (-10.96, 0.54)
# 86 Aquarii : (23.78, -18.17)
#
# Virgo:
# Spica : (-0.00, -0.00)
# Gamma Virginis : (-10.88, 9.71)
# Epsilon Virginis : (-5.76, 22.12)
# Zeta Virginis : (2.37, 10.57)
# Delta Virginis : (-7.40, 14.56)
# Beta Virginis : (-23.63, 12.93)
# Gamma Virginis : (-10.88, 9.71)
# 109 Virginis : (20.26, 13.05)
# Mu Virginis : (11.84, 1.26)
# Eta Virginis : (-16.32, 10.49)
# Nu Virginis : (17.89, 14.00)
# Iota Virginis : (12.70, 5.16)
# Omicron Virginis : (-20.00, 19.89)
# Kappa Virginis : (11.92, 0.89)
# Tau Virginis : (9.11, 12.71)
# Theta Virginis : (-3.81, 5.62)
# 110 Virginis : (24.43, 13.25)
# Lambda Virginis : (13.48, -2.21)
# Pi Virginis : (-21.08, 17.78)
# Chi Virginis : (-11.49, 3.17)
#
# Vela:
# Gamma Velorum : (0.00, 0.00)
# Delta Velorum : (8.80, -7.37)
# Lambda Velorum : (14.62, 3.90)
# Kappa Velorum : (18.15, -7.67)
# Mu Velorum : (24.35, -0.17)
# HD 82668 : (20.43, -9.70)
# Phi Velorum : (26.84, -7.23)
# Omicron Velorum : (7.69, -5.59)
# HD 78004 : (13.66, 0.24)
# HD 74180 : (7.78, 0.69)
# P Velorum : (36.95, -0.89)
# HD 88955 : (31.30, 5.21)
# HD 75063 : (9.13, 1.30)
# Psi Velorum : (20.29, 6.87)
# HD 74772 : (8.72, 4.69)
# HD 73634 : (7.03, 4.35)
# Gamma Velorum : (0.00, 0.00)
# HD 92449 : (37.45, -8.27)
# HD 83446 : (21.83, -2.02)
# HD 95370 : (42.66, 5.11)

# %%
# # Convert dictionary to JSON string
# json_string = json.dumps(data)

# Save JSON string to a file
with open('data.json', 'r') as f:
    k = f.readlines()
    f.close()
print(*k)

df.sample(20)
# Out:
# {"Aquila": [{"Altair": [-0.0, 0.0]}, {"Gamma Aquilae": [-1.14, 1.74]}, {"Zeta Aquilae": [-11.35, 5.0]}, {"Theta Aquilae": [5.13, -9.69]}, {"Delta Aquilae": [-6.33, -5.75]}, {"Lambda Aquilae": [-11.14, -13.75]}, {"Beta Aquilae": [1.13, -2.46]}, {"Eta Aquilae": [0.42, -7.86]}, {"Epsilon Aquilae": [-12.79, 6.2]}, {"12 Aquilae": [-12.28, -14.61]}, {"71 Aquilae": [11.88, -9.97]}, {"Iota Aquilae": [-3.52, -10.15]}, {"Mu Aquilae": [-2.15, 4.47]}, {"Nu Aquilae": [-1.18, 2.89]}, {"Xi Aquilae": [0.86, -0.41]}, {"69 Aquilae": [9.71, -11.75]}, {"70 Aquilae": [11.48, -11.42]}, {"Kappa Aquilae": [-3.48, -15.9]}, {"26 Aquilae": [-7.56, -14.28]}, {"4 Aquilae": [-16.49, -6.81]}], "Andromeda": [{"Alpheratz": [-0.0, 0.0]}, {"Mirach": [15.33, 6.53]}, {"Gamma Andromedae": [28.87, 13.24]}, {"Delta Andromedae": [7.73, 1.77]}, {"Andromeda Galaxy": [8.58, 12.18]}, {"51 Andromedae": [22.4, 19.54]}, {"Omicron Andromedae": [343.38, 13.24]}, {"Lambda Andromedae": [352.29, 17.37]}, {"Mu Andromedae": [35.26, 10.44]}, {"Zeta Andromedae": [9.73, -4.82]}, {"Upsilon Andromedae": [22.1, 12.32]}, {"Kappa Andromedae": [353.0, 15.24]}, {"Phi Andromedae": [15.28, 18.15]}, {"Iota Andromedae": [352.43, 14.18]}, {"Pi Andromedae": [7.12, 4.63]}, {"Epsilon Andromedae": [7.54, 0.22]}, {"Eta Andromedae": [12.2, -5.67]}, {"Sigma Andromedae": [2.48, 7.69]}, {"Nu Andromedae": [13.47, 4.66]}, {"7 Andromedae": [346.04, 20.32]}], "Sculptor": [{"Alpha Sculptoris": [0.0, 0.0]}, {"Beta Sculptoris": [338.59, -8.46]}, {"Gamma Sculptoris": [335.06, -3.17]}, {"Delta Sculptoris": [342.58, 1.23]}, {"Eta Sculptoris": [-7.67, -3.65]}, {"Zeta Sculptoris": [-14.07, -0.36]}, {"Iota Sculptoris": [-9.27, 0.38]}, {"Theta Sculptoris": [-11.72, -5.78]}, {"Pi Sculptoris": [10.89, -2.97]}, {"Epsilon Sculptoris": [11.76, 4.3]}, {"HD 9525": [8.58, -7.51]}, {"Sigma Sculptoris": [0.96, -2.19]}, {"HD 3059": [-6.23, -0.2]}, {"Xi Sculptoris": [0.68, -9.56]}, {"BU Scl": [345.22, -0.13]}, {"HD\u00a0218434": [332.44, 0.53]}, {"HD 220096": [335.66, 2.37]}], "Ara": [{"Beta Arae": [0.0, 0.0]}, {"Alpha Arae": [1.64, 5.65]}, {"Zeta Arae": [-6.66, -0.46]}, {"Gamma Arae": [0.03, -0.85]}, {"Delta Arae": [1.45, -5.15]}, {"Theta Arae": [10.34, 5.44]}, {"Eta Arae": [-8.87, -3.51]}, {"Epsilon1 Arae": [-6.42, 2.37]}, {"Sigma Arae": [2.59, 9.02]}, {"Lambda Arae": [3.78, 6.11]}, {"Mu Arae": [-1.64, -5.04]}, {"Kappa Arae": [0.18, 4.9]}, {"Iota Arae": [-0.5, 8.06]}, {"Pi Arae": [3.2, 1.03]}, {"Epsilon2 Arae": [-5.53, 2.29]}, {"HD 157661": [0.4, 9.69]}, {"HD 150898": [-9.49, -2.81]}, {"HD 150168": [-10.9, 5.88]}], "Libra": [{"Beta Librae": [0.0, -0.0]}, {"Alpha Librae": [-6.53, -6.66]}, {"Sigma Librae": [-3.23, -15.9]}, {"Upsilon Librae": [5.01, -18.75]}, {"Tau Librae": [5.41, -20.39]}, {"Gamma Librae": [4.63, -5.41]}, {"Theta Librae": [9.21, -7.35]}, {"16 Librae": [-4.95, 5.04]}, {"Iota1 Librae": [-1.19, -10.41]}, {"37 Librae": [4.29, -0.68]}, {"Kappa Librae": [6.24, -10.3]}, {"Delta Librae": [-4.01, 0.86]}, {"Epsilon Librae": [1.8, -0.94]}, {"11 Librae": [-6.5, 7.08]}, {"48 Librae": [10.3, -4.9]}, {"42 Librae": [5.82, -14.44]}, {"Lambda Librae": [9.08, -10.78]}, {"Alpha Librae": [-6.53, -6.66]}, {"Mu Librae": [-5.09, 8.44]}, {"49 Librae": [10.83, -7.15]}], "Cetus": [{"Beta Ceti": [-0.0, -0.0]}, {"Alpha Ceti": [34.67, 22.08]}, {"Mira": [23.94, 15.01]}, {"Eta Ceti": [6.25, 7.8]}, {"Gamma Ceti": [29.93, 21.22]}, {"Tau Ceti": [15.12, 2.05]}, {"Iota Ceti": [-6.04, 9.16]}, {"Theta Ceti": [10.11, 9.8]}, {"Zeta Ceti": [16.97, 7.65]}, {"Upsilon Ceti": [19.1, -3.09]}, {"Delta Ceti": [28.97, 18.32]}, {"Pi Ceti": [30.13, 4.13]}, {"Xi2 Ceti": [26.14, 26.45]}, {"Xi1 Ceti": [22.35, 26.83]}, {"7 Ceti": [-7.24, -0.95]}, {"2 Ceti": [-9.97, 0.65]}, {"Chi Ceti": [16.5, 7.3]}, {"Lambda Ceti": [34.03, 26.89]}, {"Sigma Ceti": [27.12, 2.74]}], "Aries": [{"Hamal": [0.0, 0.0]}, {"Beta Arietis": [-3.13, -2.65]}, {"41 Arietis": [10.71, 3.8]}, {"Delta Arietis": [16.12, -3.74]}, {"HD 20644": [18.29, 5.59]}, {"39 Arietis": [10.19, 5.78]}, {"Gamma Arietis" ...
#        Constellation           Star Name  x coordinate  y coordinate
# 1351          Pisces     Omicron Piscium          3.48         -6.19
# 914        Monoceros       3 Monocerotis        -24.85         -1.05
# 689           Fornax    Lambda2 Fornacis         -8.78         -5.59
# 685           Fornax              AI For          1.88          4.86
# 688           Fornax      Iota1 Fornacis         -8.98         -1.06
# 5             Aquila      Lambda Aquilae        -11.14        -13.75
# 362   Coma Berenices  13 Comae Berenices        -11.89         -1.78
# 901          Lacerta           HD 216174          4.62          5.62
# 1294       Vulpecula        1 Vulpeculae         -3.13         -3.27
# 1035          Antlia       Zeta1 Antliae        -14.10         -0.82
# 274           Carina         Chi Carinae         23.20         -0.29
# 941              Leo             Regulus          0.00          0.00
# 1120        Ophiucus      Kappa Ophiuchi         -9.31         -3.18
# 1194          Pictor       Beta Pictoris        -15.23         10.87
# 1555          Taurus             Alcyone        -12.11          7.60
# 126            Aries       Kappa Arietis         -0.15         -0.81
# 810       Horologium     Delta Horologii         -0.79          0.30
# 725   Camelopardalis            HD 24479        -16.49          2.63
# 760       Ursa Major  Iota Ursae Majoris        -58.71         -7.92
# 2             Aquila        Zeta Aquilae        -11.35          5.00

# %% [markdown]
# **Change of Basis (for the coordinates)**

# %%
import numpy as np, matplotlib.pyplot as plt, random as rd

coordinates = np.array([[rd.randint(1,10) for j in range(2)] for i in range(10)])
print(coordinates, '\n')

new_basis = np.array([
    [0.5,0],
    [0,1]
])

new_coordinates = np.matmul(coordinates, np.linalg.inv(new_basis))

print(new_coordinates)
# Out:
# [[ 9  5]
#  [ 7  3]
#  [ 7  4]
#  [ 8 10]
#  [ 8  7]
#  [ 4 10]
#  [ 6  4]
#  [ 5 10]
#  [ 1  8]
#  [ 7  3]]
#
# [[18.  5.]
#  [14.  3.]
#  [14.  4.]
#  [16. 10.]
#  [16.  7.]
#  [ 8. 10.]
#  [12.  4.]
#  [10. 10.]
#  [ 2.  8.]
#  [14.  3.]]

# %% [markdown]
# **Old Code Starts Here**

# %%
# Import the necessary modules
from astropy import units as u
from astropy.coordinates import SkyCoord, get_constellation

# Define a list of 88 constellations (for reference)
constellations = [
        "Aquila", "Andromeda", "Sculptor", "Ara", "Libra", "Cetus", "Aries",
        "Scutum", "Pyxis", "Bootes", "Caelum", "Chamaeleon", "Cancer", "Capricornus", "Carina", "Cassiopeia",
        "Centaurus", "Cepheus", "Coma Berenices", "Canes Venatici", "Auriga", "Columba", "Circinus", "Crater",
        "Corona Australis", "Corona Borealis", "Corvus", "Crux", "Cygnus", "Delphinus", "Dorado", "Draco",
        "Norma", "Eridanus", "Sagitta", "Fornax", "Gemini", "Camelopardalis", "Canis Major", "Ursa Major",
        "Grus", "Hercules", "Horologium", "Hydra", "Hydrus", "Indus", "Lacerta", "Monoceros", "Lepus", "Leo",
        "Lupus", "Lynx", "Lyra", "Antlia", "Microscopium", "Musca", "Octans", "Apus", "Ophiuchus", "Orion",
        "Pavo", "Pegasus", "Pictor", "Perseus", "Equuleus", "Canis Minor", "Leo Minor", "Vulpecula",
        "Ursa Minor", "Phoenix", "Pisces", "Piscis Austrinus", "Volans", "Puppis", "Reticulum", "Sagittarius",
        "Scorpius", "Scutum", "Serpens", "Sextans", "Mensa", "Taurus", "Telescopium", "Tucana", "Triangulum",
        "Triangulum Australe", "Aquarius", "Virgo", "Vela"
    ]

'''
This code is no longer required

# Define a list of list of stars for each of the 88 constellations
stars_list = [['Altair','Alshain','Tarazed','Epsilon Aquilae','Zeta Aquilae','Eta Aquilae','Theta Aquilae','Iota Aquilae'],
              ['Alpheratz','Mirach','Almach','Adhil','Segin','Nembus','Angetenar','Tau Andromedae','Delta Andromedae','Upsilon Andromedae','Zeta Andromedae','Rho Andromedae','Pi Andromedae','Iota Andromedae','Lambda Andromedae','Kappa Andromedae'],
              ['Alpha Sculptoris','Beta Sculptoris','Gamma Sculptoris','Delta Sculptoris','Epsilon Sculptoris'],
              ['Alpha Arae','Beta Arae','Zeta Arae','Gamma Arae','Delta Arae','Theta Arae','Eta Arae'],
              ['Alpha Librae','Beta Librae','Gamma Librae','Delta Librae','Sigma Librae','Mu Librae','Nu Librae','42 Librae'],
              ['Alpha Ceti','Beta Ceti','Gamma Ceti','Delta Ceti','Epsilon Ceti','Zeta Ceti','Eta Ceti','Theta Ceti','Iota Ceti','Kappa Ceti','Lambda Ceti','Omicron Ceti'], # requires 15 but only 13 stars work
              ['Hamal','Sheratan','Mesarthim','Botein','Alderamin']
             ]
'''

# Define the coordinates of the brightest star of each constellation
coordinates = [SkyCoord(ra=297.70*u.deg, dec=8.8683*u.deg),
               SkyCoord(ra=2.10*u.deg, dec=29.0906*u.deg),
               SkyCoord(ra=14.65*u.deg, dec=-29.3574*u.deg),
               SkyCoord(ra=262.96*u.deg, dec=-49.8761*u.deg),
               SkyCoord(ra=222.72*u.deg, dec=-16.0416*u.deg)
              ]

# Loop over the stars and print their coordinates
for stars in stars_list:
    # Get the coordinate object of the first star
    coord_one = SkyCoord.from_name(stars[0])
    # Get the constellation of the first star
    constellation = get_constellation(coord_one)
    print(f"{constellation}: ")

    # Define the reference frame and origin
    frame = 'icrs'
    origin = coordinates[stars_list.index(stars)]

    for star in stars:
      # Calculate the relative coordinates to the origin
      coord = SkyCoord.from_name(star)
      dx = (coord.ra - origin.ra).to(u.deg).value
      dy = (coord.dec - origin.dec).to(u.deg).value

      # Print the star name and coordinates
      print(f"{star} : ({dx:.2f}, {dy:.2f})")

    print()
# Out:
# Aquila:
# Altair : (-0.00, 0.00)
# Alshain : (1.13, -2.46)
# Tarazed : (-1.14, 1.74)
# Epsilon Aquilae : (-12.79, 6.20)
# Zeta Aquilae : (-11.35, 5.00)
# Eta Aquilae : (0.42, -7.86)
# Theta Aquilae : (5.13, -9.69)
# Iota Aquilae : (-3.52, -10.15)
#
# Andromeda:
# Alpheratz : (-0.00, -0.00)
# Mirach : (15.33, 6.53)
# Almach : (28.87, 13.24)
# Adhil : (18.49, 16.44)
# Segin : (26.50, 34.58)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-e7f40f2e8c49> in <cell line: 37>()
#      48     for star in stars:
#      49       # Calculate the relative coordinates to the origin
# ---> 50       coord = SkyCoord.from_name(star)
#      51       dx = (coord.ra - origin.ra).to(u.deg).value
#      52       dy = (coord.dec - origin.dec).to(u.deg).value
#
# /usr/local/lib/python3.10/dist-packages/astropy/coordinates/sky_coordinate.py in from_name(cls, name, frame, parse, cache)
#    2204         from .name_resolve import get_icrs_coordinates
#    2205
# -> 2206         icrs_coord = get_icrs_coordinates(name, parse, cache=cache)
#    2207         icrs_sky_coord = cls(icrs_coord)
#    2208         if frame in ("icrs", icrs_coord.__class__):
#
# /usr/local/lib/python3.10/dist-packages/astropy/coordinates/name_resolve.py in get_icrs_coordinates(name, parse, cache)
#     166         try:
#     167             resp_data = get_file_contents(
# --> 168                 download_file(url, cache=cache, show_progress=False)
#     169             )
#     170             break
#
# /usr/local/lib/python3.10/dist-packages/astropy/utils/data.py in download_file(remote_url, cache, show_progress, timeout, sources, pkgname, http_headers, ssl_context, allow_insecure)
#    1498     for source_url in sources:
#    1499         try:
# -> 1500             f_name = _download_file_from_source(
#    1501                 source_url,
#    1502                 timeout=timeout,
#
# /usr/local/lib/python3.10/dist-packages/astropy/utils/data.py in _download_file_from_source(source_url, show_progress, timeout, remote_url, cache, pkgname, http_headers, ftp_tls, ssl_context, allow_insecure)
#    1282                 raise
#    1283
# -> 1284     with _try_url_open(
#    1285         source_url,
#    1286         timeout=timeout,
#
# /usr/local/lib/python3.10/dist-packages/astropy/utils/data.py in _try_url_open(source_url, timeout, http_headers, ftp_tls, ssl_context, allow_insecure)
#    1200
#    1201     try:
# -> 1202         return urlopener.open(req, timeout=timeout)
#    1203     except urllib.error.URLError as exc:
#    1204         reason = exc.reason
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     517
#     518         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519         response = self._open(req, data)
#     520
#     521         # post-process response
#
# /usr/lib/python3.10/urllib/request.py in _open(self, req, data)
#     534
#     535         protocol = req.type
# --> 536         result = self._call_chain(self.handle_open, protocol, protocol +
#     537                                   '_open', req)
#     538         if result:
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in https_open(self, req)
#    1389
#    1390         def https_open(self, req):
# -> 1391             return self.do_open(http.client.HTTPSConnection, req,
#    1392                 context=self._context, check_hostname=self._check_hostname)
#    1393
#
# /usr/lib/python3.10/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1350             except OSError as err: # timeout error
#    1351                 raise URLError(err)
# -> 1352             r = h.getresponse()
#    1353         except:
#    1354             h.close()
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Import the necessary modules
import numpy as np
from astropy import units as u
from astropy.coordinates import SkyCoord, Distance
# !pip install astroquery
from astroquery.gaia import Gaia

# Set the row limit for returned data
Gaia.ROW_LIMIT = 10000

# Define a function to get the coordinates of the brightest star in a constellation
def get_brightest_star(constellation):
    # Query the Gaia catalog for stars in the given constellation
    query = f"SELECT TOP 1 * FROM gaiadr2.gaia_source WHERE CONTAINS(POINT('ICRS',gaiadr2.gaia_source.ra,gaiadr2.gaia_source.dec),CIRCLE('ICRS',6.0,0.0,180.0))=1 AND phot_g_mean_mag IS NOT NULL AND parallax IS NOT NULL AND constellation_name = '{constellation}' ORDER BY phot_g_mean_mag ASC"
    job = Gaia.launch_job_async(query)
    table = job.get_results()

    # Extract the relevant columns from the table
    ra = table['ra'][0] * u.deg # Right ascension
    dec = table['dec'][0] * u.deg # Declination
    plx = table['parallax'][0] * u.mas # Parallax
    gmag = table['phot_g_mean_mag'][0] # G-band magnitude

    # Create a SkyCoord object for the star
    star = SkyCoord(ra=ra, dec=dec, distance=Distance(parallax=plx), frame='icrs')

    # Return the star and its magnitude
    return star, gmag

# Define a function to get the coordinates of all the major stars in a constellation
def get_major_stars(constellation):
    # Query the Gaia catalog for stars in the given constellation with magnitude less than 6
    query = f"SELECT * FROM gaiadr2.gaia_source WHERE CONTAINS(POINT('ICRS',gaiadr2.gaia_source.ra,gaiadr2.gaia_source.dec),CIRCLE('ICRS',6.0,0.0,180.0))=1 AND phot_g_mean_mag IS NOT NULL AND parallax IS NOT NULL AND constellation_name = '{constellation}' AND phot_g_mean_mag < 6 ORDER BY phot_g_mean_mag ASC"
    job = Gaia.launch_job_async(query)
    table = job.get_results()

    # Extract the relevant columns from the table
    ra = table['ra'] * u.deg # Right ascension
    dec = table['dec'] * u.deg # Declination
    plx = table['parallax'] * u.mas # Parallax
    gmag = table['phot_g_mean_mag'] # G-band magnitude

    # Create a SkyCoord object for the stars
    stars = SkyCoord(ra=ra, dec=dec, distance=Distance(parallax=plx), frame='icrs')

    # Return the stars and their magnitudes
    return stars, gmag

# Define a function to print the coordinates of all the major stars in a constellation
def print_coordinates(constellation):
    # Get the brightest star and its magnitude
    brightest_star, brightest_mag = get_brightest_star(constellation)

    # Get the major stars and their magnitudes
    major_stars, major_mags = get_major_stars(constellation)

    # Print the name of the constellation and the number of major stars
    print(f"Constellation: {constellation}")
    print(f"Number of major stars: {len(major_stars)}")

    # Print the coordinates of the brightest star as the origin
    print(f"Brightest star: (0, 0, 0), magnitude = {brightest_mag:.2f}")

    # Loop over the major stars
    for i, star in enumerate(major_stars):
        # Skip the brightest star
        if star == brightest_star:
            continue

        # Calculate the relative coordinates of the star with respect to the brightest star
        dx = star.cartesian.x - brightest_star.cartesian.x
        dy = star.cartesian.y - brightest_star.cartesian.y
        dz = star.cartesian.z - brightest_star.cartesian.z

        # Print the coordinates and the magnitude of the star
        print(f"Star {i+1}: ({dx.value:.2f}, {dy.value:.2f}, {dz.value:.2f}), magnitude = {major_mags[i]:.2f}")

    # Print a blank line
    print()

# Define a list of all 88 constellations
constellations = ['Andromeda', 'Antlia', 'Apus', 'Aquarius', 'Aquila', 'Ara', 'Aries', 'Auriga', 'Bootes', 'Caelum', 'Camelopardalis', 'Cancer', 'Canes Venatici', 'Canis Major', 'Canis Minor', 'Capricornus', 'Carina', 'Cassiopeia', 'Centaurus', 'Cepheus', 'Cetus', 'Chamaeleon', 'Circinus', 'Columba', 'Coma Berenices', 'Corona Australis', 'Corona Borealis', 'Corvus', 'Crater', 'Crux', 'Cygnus', 'Delphinus', 'Dorado', 'Draco', 'Equuleus', 'Eridanus', 'Fornax', 'Gemini', 'Grus', 'Hercules', 'Horologium', 'Hydra', 'Hydrus', 'Indus', 'Lacerta', 'Leo', 'Leo Minor', 'Lepus', 'Libra', 'Lupus', 'Lynx', 'Lyra', 'Mensa', 'Microscopium', 'Monoceros', 'Musca', 'Norma', 'Octans', 'Ophiuchus', 'Orion', 'Pavo', 'Pegasus', 'Perseus', 'Phoenix', 'Pictor', 'Pisces', 'Piscis Austrinus', 'Puppis', 'Pyxis', 'Reticulum', 'Sagitta', 'Sagittarius', 'Scorpius', 'Sculptor', 'Scutum', 'Serpens', 'Sextans', 'Taurus', 'Telescopium', 'Triangulum', 'Triangulum Australe', 'Tucana', 'Ursa Major', 'Ursa Minor', 'Vela', 'Virgo', 'Volans', 'Vulpecula']

# Loop over the constellations and print the coordinates of their major stars
for constellation in constellations:
    print(constellation)
    print_coordinates(constellation)
# Out:
# Andromeda
# 500 Error 500:
# null
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-76f58564f583> in <cell line: 85>()
#      85 for constellation in constellations:
#      86     print(constellation)
# ---> 87     print_coordinates(constellation)
#
# <ipython-input-6-76f58564f583> in print_coordinates(constellation)
#      50 def print_coordinates(constellation):
#      51     # Get the brightest star and its magnitude
# ---> 52     brightest_star, brightest_mag = get_brightest_star(constellation)
#      53
#      54     # Get the major stars and their magnitudes
#
# <ipython-input-6-76f58564f583> in get_brightest_star(constellation)
#      13     # Query the Gaia catalog for stars in the given constellation
#      14     query = f"SELECT TOP 1 * FROM gaiadr2.gaia_source WHERE CONTAINS(POINT('ICRS',gaiadr2.gaia_source.ra,gaiadr2.gaia_source.dec),CIRCLE('ICRS',6.0,0.0,180.0))=1 AND phot_g_mean_mag IS NOT NULL AND parallax IS NOT NULL AND constellation_name = '{constellation}' ORDER BY phot_g_mean_mag ASC"
# ---> 15     job = Gaia.launch_job_async(query)
#      16     table = job.get_results()
#      17
#
# /usr/local/lib/python3.10/dist-packages/astroquery/gaia/core.py in launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name, autorun)
#     901         A Job object
#     902         """
# --> 903         return TapPlus.launch_job_async(self, query=query,
#     904                                         name=name,
#     905                                         output_file=output_file,
#
# /usr/local/lib/python3.10/dist-packages/astroquery/utils/tap/core.py in launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name, autorun)
#     457                         job.save_results(verbose)
#     458                     else:
# --> 459                         job.get_results()
#     460                         log.info("Query finished.")
#     461         return job
#
# /usr/local/lib/python3.10/dist-packages/astroquery/utils/tap/model/job.py in get_results(self)
#     244         else:
#     245             # async: result is in the server once the job is finished
# --> 246             self.__load_async_job_results()
#     247             return self.results
#     248
#
# /usr/local/lib/python3.10/dist-packages/astroquery/utils/tap/model/job.py in __load_async_job_results(self, debug)
#     351                                                              debug)
#     352         isError = self.connHandler.\
# --> 353             check_launch_response_status(resultsResponse,
#     354                                          debug,
#     355                                          200)
#
# /usr/local/lib/python3.10/dist-packages/astroquery/utils/tap/conn/tapconn.py in check_launch_response_status(self, response, debug, expected_response_status, raise_exception)
#     681             errMsg = taputils.get_http_response_error(response)
#     682             print(response.status, errMsg)
# --> 683             raise requests.exceptions.HTTPError(errMsg)
#     684         else:
#     685             return isError
#
# HTTPError: Error 500:
# null

# %%
# !pip install astroquery
from astroquery.gaia import Gaia
from astroquery.simbad import Simbad

def get_star_data(star_name):
    result_table = Simbad.query_object(star_name)
    print(result_table)

get_star_data("Hamal")
# Out:
# Collecting astroquery
#   Downloading astroquery-0.4.6-py3-none-any.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from astroquery) (1.25.2)
# Requirement already satisfied: astropy>=4.0 in /usr/local/lib/python3.10/dist-packages (from astroquery) (5.3.4)
# Requirement already satisfied: requests>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from astroquery) (2.31.0)
# Requirement already satisfied: beautifulsoup4>=4.3.2 in /usr/local/lib/python3.10/dist-packages (from astroquery) (4.12.3)
# Requirement already satisfied: html5lib>=0.999 in /usr/local/lib/python3.10/dist-packages (from astroquery) (1.1)
# Requirement already satisfied: keyring>=4.0 in /usr/lib/python3/dist-packages (from astroquery) (23.5.0)
# Collecting pyvo>=1.1 (from astroquery)
#   Downloading pyvo-1.5.1-py3-none-any.whl (910 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.2/910.2 kB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.0->astroquery) (2.0.1.1)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.0->astroquery) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.0->astroquery) (23.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.3.2->astroquery) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery) (2024.2.2)
# Installing collected packages: pyvo, astroquery
# Successfully installed astroquery-0.4.6 pyvo-1.5.1
#  MAIN_ID        RA           DEC      ...     COO_BIBCODE     SCRIPT_NUMBER_ID
#              "h:m:s"       "d:m:s"    ...
# --------- ------------- ------------- ... ------------------- ----------------
# * alf Ari 02 07 10.4057 +23 27 44.703 ... 2007A&A...474..653V                1
