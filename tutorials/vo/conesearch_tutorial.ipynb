# %% [markdown]
# # VO Simple Cone Search Tutorial

# %% [markdown]
# This tutorial requires `astropy` 0.3 or greater because the `vo` package is a new feature introduced in that version.

# %%
# Python 3 compatibility
from __future__ import absolute_import, division, print_function

# Astropy
import astropy

# Do NOT proceed if printed version number is less than 0.3
print(astropy.__version__)
# Out:
# 0.4.dev6797

# %%
# Import conesearch
from astropy.vo.client import conesearch

# %% [markdown]
# It might be useful to list the available Cone Search catalogs first. By default, catalogs that pass nightly validation are included. Validation is hosted by Space Telescope Science Institute (STScI).

# %%
conesearch.list_catalogs()
# Out:
# [u'Guide Star Catalog 2.3 1',
#  u'SDSS DR7 - Sloan Digital Sky Survey Data Release 7 1',
#  u'SDSS DR7 - Sloan Digital Sky Survey Data Release 7 2',
#  u'SDSS DR7 - Sloan Digital Sky Survey Data Release 7 3',
#  u'SDSS DR7 - Sloan Digital Sky Survey Data Release 7 4',
#  u'The HST Guide Star Catalog, Version 1.1 (Lasker+ 1992) 1',
#  u'The HST Guide Star Catalog, Version 1.2 (Lasker+ 1996) 1',
#  u'The HST Guide Star Catalog, Version GSC-ACT (Lasker+ 1996-99) 1',
#  u'The PMM USNO-A1.0 Catalogue (Monet 1997) 1',
#  u'The USNO-A2.0 Catalogue (Monet+ 1998) 1',
#  u'Two Micron All Sky Survey (2MASS) 1',
#  u'Two Micron All Sky Survey (2MASS) 2',
#  u'USNO-A2 Catalogue 1',
#  u'USNO-A2.0 1']

# %% [markdown]
# Next, let's pick an astronomical object of interest. For example, M31.

# %%
from astropy import coordinates as coord

c = coord.ICRSCoordinates.from_name('M31')
print(c)
# Out:
# <ICRS RA=10.68471 deg, Dec=41.26875 deg>

# %% [markdown]
# By default, a basic Cone Search goes through the list of catalogs and *stops* at the first one that returns non-empty VO table. Let's search for objects within 0.1 degree around M31. You will see a lot of warnings that were generated by VO table parser but ignored by Cone Search service validator. VO compliance enforced by Cone Search providers is beyond the control of `astropy.vo` package.

# %%
from astropy import units as u

result = conesearch.conesearch(c, 0.1 * u.degree)
# Out:
# Trying http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=PhotoObjAll&
# WARNING
# : W25: ?:?:?: W25: 'http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=PhotoObjAll&' failed with: <urlopen error timed out> [astropy.io.votable.exceptions]
# Trying http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&
# Downloading http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1 -
# Downloading http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1 [Done]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:66:0: W50: Invalid unit string 'deg/day' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:69:0: W50: Invalid unit string 'deg/day' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:72:0: W50: Invalid unit string 'deg/day' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:75:0: W50: Invalid unit string 'deg/day' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:138:0: W50: Invalid unit string 'maggies/arcsec^2' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:141:0: W50: Invalid unit string 'maggies/arcsec^2' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:144:0: W50: Invalid unit string 'maggies/arcsec^2' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:147:0: W50: Invalid unit string 'maggies/arcsec^2' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:150:0: W50: Invalid unit string 'maggies/arcsec^2' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:153:0: W50: Invalid unit string 'maggies/arcsec^2' (suppressing further warnings of this type...) [astropy.io.votable.exceptions]
# WARNING
# : W25: ?:?:?: W25: 'http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&' failed with: Catalog server 'http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Galaxy&' returned 0 result [astropy.io.votable.exceptions]
# Trying http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&
# Downloading http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1 -
# Downloading http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1 [Done]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:66:0: W50: Invalid unit string 'deg/day' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:69:0: W50: Invalid unit string 'deg/day' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:72:0: W50: Invalid unit string 'deg/day' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:75:0: W50: Invalid unit string 'deg/day' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:138:0: W50: Invalid unit string 'maggies/arcsec^2' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:141:0: W50: Invalid unit string 'maggies/arcsec^2' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:144:0: W50: Invalid unit string 'maggies/arcsec^2' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:147:0: W50: Invalid unit string 'maggies/arcsec^2' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:150:0: W50: Invalid unit string 'maggies/arcsec^2' [astropy.io.votable.exceptions]
# WARNING: W50: http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:153:0: W50: Invalid unit string 'maggies/arcsec^2' (suppressing further warnings of this type...) [astropy.io.votable.exceptions]
# WARNING
# : W25: ?:?:?: W25: 'http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&' failed with: Catalog server 'http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&' returned 0 result [astropy.io.votable.exceptions]
# Trying http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/243/out&
# Downloading http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/243/out&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1 -
# Downloading http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/243/out&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1 [Done]
# WARNING: W22: http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/243/out&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:15:0: W22: The DEFINITIONS element is deprecated in VOTable 1.1.  Ignoring [astropy.io.votable.exceptions]

# %%
print('First non-empty table returned by', result.url)
print('Number of rows is', result.nrows)
# Out:
# First non-empty table returned by http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/243/out&
# Number of rows is 3

# %% [markdown]
# Extract metadata of this Cone Search catalog.

# %%
from astropy.vo.client import vos_catalog

my_db = vos_catalog.get_remote_catalog_db(conesearch.CONESEARCH_DBNAME())
my_cat = my_db.get_catalog_by_url(result.url)
print(my_cat.dumps())
# Out:
# {
#     "capabilityClass": "ConeSearch",
#     "capabilityStandardID": "ivo://ivoa.net/std/ConeSearch",
#     "capabilityValidationLevel": "",
#     "contentLevel": "#Research#",
#     "description": "USNO-A1.0 is a catalog of 488,006,860 sources whose positions can be used for astrometric references. These sources were detected by the Precision Measuring Machine (PMM) built and operated by the U. S. Naval Observatory Flagstaff Station during the scanning and processing of the Palomar Observatory Sky Survey I (POSS-I) O and E plates, the UK Science Research Council SRC-J survey plates, and the European Southern Observatory ESO-R survey plates. The PMM detects and processes at and beyond the nominal limiting magnitude of these surveys, but the large number of spurious detections requires that a filter be used to eliminate as many as possible. USNO-A's sole inclusion requirement was that there be spatially coincident detections (within a 2 arcsecond radius aperture) on the blue and red survey plate. For field centers of -30 degrees and above, data come from POSS-I plates, while data from field centers of -35 and below come from SRC-J and ESO-R plates.\n\nThis particular record describes access specifically to the \"out\" table within this catalog through the VO-standard ConeSearch service interface.  It can be used automatically by compliant tools and applications.  Consult the referenceURL for more information about this table.",
#     "duplicatesIgnored": 0,
#     "identifier": "ivo://CDS.VizieR/I/243#out",
#     "interfaceClass": "ParamHTTP",
#     "interfaceRole": "std?",
#     "interfaceVersion": "",
#     "maxRadius": 180.0,
#     "maxRecords": 9999,
#     "publisher": "CDS",
#     "publisherID": "ivo://CDS",
#     "referenceURL": "http://cdsarc.u-strasbg.fr/cgi-bin/Cat?I/243",
#     "regionOfRegard": NaN,
#     "resourceID": "ivo://CDS.VizieR/I/243",
#     "shortName": "I/243",
#     "subject": "##",
#     "tags": "Catalog",
#     "title": "The PMM USNO-A1.0 Catalogue (Monet 1997)",
#     "type": "#Catalog#",
#     "updated": "2011-09-14T20:18:18",
#     "url": "http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/243/out&",
#     "validate_expected": "good",
#     "validate_network_error": null,
#     "validate_nexceptions": 0,
#     "validate_nwarnings": 3,
#     "validate_out_db_name": "good",
#     "validate_version": "1.1",
#     "validate_warning_types": [
#         "W22",
#         "W03"
#     ],
#     "validate_warnings": [
#         "/eng/ssb/web/astrolib/vo_databases/daily_20131216/results/f0/d0/523499685e72a29898cbe7c057a6/vo.xml:15:0: W22: The DEFINITIONS element is deprecated in VOTable 1.1.  Ignoring",
#         "/eng/ssb/web/astrolib/vo_databases/daily_20131216/results/f0/d0/523499685e72a29898cbe7c057a6/vo.xml:59:4: W03: Implictly generating an ID from a name 'RA(ICRS)' -> 'RA_ICRS_'",
#         "/eng/ssb/web/astrolib/vo_databases/daily_20131216/results/f0/d0/523499685e72a29898cbe7c057a6/vo.xml:62:4: W03: Implictly generating an ID from a name 'DE(ICRS)' -> 'DE_ICRS_'"
#     ],
#     "validate_xmllint": true,
#     "validate_xmllint_content": "/eng/ssb/web/astrolib/vo_databases/daily_20131216/results/f0/d0/523499685e72a29898cbe7c057a6/vo.xml validates\n",
#     "version": "18-Jul-1998",
#     "waveband": "#Optical#"
# }

# %% [markdown]
# If you have a favorite catalog in mind, you can also perform Cone Search only on that catalog.

# %%
result = conesearch.conesearch(
    c, 0.1 * u.degree, catalog_db='The USNO-A2.0 Catalogue (Monet+ 1998) 1')
# Out:
# Trying http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/252/out&
# Downloading http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/252/out&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1 -
# Downloading http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/252/out&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1 [Done]
# WARNING: W22: http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/252/out&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:15:0: W22: The DEFINITIONS element is deprecated in VOTable 1.1.  Ignoring [astropy.io.votable.exceptions]

# %%
print('Number of rows is', result.nrows)
# Out:
# Number of rows is 3

# %% [markdown]
# Let's explore the 3 rows of astronomical objects found within 0.1 degree of M31 in the given catalog and sort them by increasing distance. For this example, the VO table has 4 columns:
#
# * `_r` = Distance of object, in degrees, from M31
# * `_RAJ2000` = Right ascension of the object (epoch=J2000)
# * `_DEJ2000` = Declination of the object (epoch=J2000)
# * `USNO-A2.0` = Catalog ID of the object
#
# Note that column names, meanings, order, etc. might vary from catalog to catalog.

# %%
data_array = result.array.data
print(data_array)
# Out:
# [(0.094265, 10.595878, 41.335328, '1275-00425574')
#  (0.09804, 10.639945, 41.360845, '1275-00427192')
#  (0.06328, 10.712834, 41.209109, '1275-00429939')]

# %%
col_names = data_array.dtype.names
print(col_names)
# Out:
# ('_r', '_RAJ2000', '_DEJ2000', 'USNO-A2.0')

# %%
import numpy as np

distance = data_array['_r']
sorted_indices = np.argsort(distance)
sorted_data_array = data_array[sorted_indices]
print(sorted_data_array)
# Out:
# [(0.06328, 10.712834, 41.209109, '1275-00429939')
#  (0.094265, 10.595878, 41.335328, '1275-00425574')
#  (0.09804, 10.639945, 41.360845, '1275-00427192')]

# %% [markdown]
# You can also convert the distance to arcseconds.

# %%
distance_field = result.get_field_by_id('_r')
print('Field title:', distance_field.title)
print('Unit is', distance_field.unit)
# Out:
# Field title: Distance from center (010.684708+41.268750)[FK5/J2000], at Epoch of catalog (Epoch)
# Unit is deg

# %%
distance_arcsec = distance_field.unit.to(u.arcsec, distance)

for d_deg, d_arcsec in zip(distance, distance_arcsec):
    print(d_deg, 'deg converted to', d_arcsec, 'arcsec')
# Out:
# 0.094265 deg converted to 339.354 arcsec
# 0.09804 deg converted to 352.944 arcsec
# 0.06328 deg converted to 227.808 arcsec

# %% [markdown]
# What if you want *all* the results from *all* the catalogs? And you also want to suppress all the VO table warnings and informational messages?
#
# __Warning: This can be time and resource intensive.__

# %%
import warnings

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    all_results = conesearch.search_all(c, 0.1 * u.degree, verbose=False)

# %%
for url, tab in all_results.items():
    print(url, 'returned', tab.nrows, 'rows')
# Out:
# http://www.nofs.navy.mil/cgi-bin/vo_cone.cgi?CAT=USNO-A2& returned 3 rows
# http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/243/out& returned 3 rows
# http://wfaudata.roe.ac.uk/twomass-dsa/DirectCone?DSACAT=TWOMASS&DSATAB=twomass_psc& returned 2008 rows
# http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/255/out& returned 5 rows
# http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/254/out& returned 5 rows
# http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/252/out& returned 3 rows
# http://archive.noao.edu/nvo/usno.php?cat=a& returned 10 rows
# http://gsss.stsci.edu/webservices/vo/ConeSearch.aspx?CAT=GSC23& returned 4028 rows
# http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/220/out& returned 5 rows
# http://wfaudata.roe.ac.uk/twomass-dsa/DirectCone?DSACAT=TWOMASS&DSATAB=twomass_xsc& returned 25 rows

# %%
my_favorite_result = all_results['http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/220/out&']
print(my_favorite_result.array.data.dtype.names)
print(my_favorite_result.array.data)
# Out:
# ('_r', '_RAJ2000', '_DEJ2000', 'GSC')
# [(0.063449, 10.71207, 41.20873, '0280102008')
#  (0.043453, 10.68782, 41.22536, '0280102015')
#  (0.09617, 10.80558, 41.23727, '0280102081')
#  (0.066633, 10.60025, 41.24853, '0280102017')
#  (0.082097, 10.64539, 41.34535, '0280502180')]

# %% [markdown]
# Asynchronous versions (i.e., search will run in the background) of `conesearch()` and `search_all()` are also available. Result can be obtained using the asynchronous instance's `get()` method that returns the result upon completion or after a given `timeout` value in seconds.

# %%
import time

async_search = conesearch.AsyncConeSearch(
    c, 0.1 * u.degree, catalog_db='The USNO-A2.0 Catalogue (Monet+ 1998) 1')
print('Am I running?', async_search.running())

time.sleep(3)
print('After 3 seconds. Am I done?', async_search.done())
print()

result = async_search.get(timeout=30)
print('Number of rows returned is', result.nrows)
# Out:
# Am I running? True
# After 3 seconds. Am I done?
#  True
#
# Number of rows returned is 3

# %%
async_search_all = conesearch.AsyncSearchAll(c, 0.1 * u.degree)
print('Am I running?', async_search_all.running())
print('Am I done?', async_search_all.done())
print()

all_results = async_search_all.get(timeout=30)
for url, tab in all_results.items():
    print(url, 'returned', tab.nrows, 'rows')
# Out:
# Am I running? True
# Am I done? False
#
# WARNING
# : W25: ?:?:?: W25: 'http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&' failed with: Catalog server 'http://wfaudata.roe.ac.uk/sdssdr7-dsa/DirectCone?DSACAT=SDSS_DR7&DSATAB=Star&' returned 0 result (suppressing further warnings of this type...) [astropy.io.votable.exceptions]
# http://www.nofs.navy.mil/cgi-bin/vo_cone.cgi?CAT=USNO-A2&
#  returned 3 rows
# http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/243/out& returned 3 rows
# http://wfaudata.roe.ac.uk/twomass-dsa/DirectCone?DSACAT=TWOMASS&DSATAB=twomass_psc& returned 2008 rows
# http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/255/out& returned 5 rows
# http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/254/out& returned 5 rows
# http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/252/out& returned 3 rows
# http://archive.noao.edu/nvo/usno.php?cat=a& returned 10 rows
# http://gsss.stsci.edu/webservices/vo/ConeSearch.aspx?CAT=GSC23& returned 4028 rows
# http://vizier.u-strasbg.fr/viz-bin/votable/-A?-source=I/220/out& returned 5 rows
# http://wfaudata.roe.ac.uk/twomass-dsa/DirectCone?DSACAT=TWOMASS&DSATAB=twomass_xsc& returned 25 rows

# %% [markdown]
# Let's predict the run time of performing Cone Search on `http://gsss.stsci.edu/webservices/vo/ConeSearch.aspx?CAT=GSC23&` with a radius of 0.5 degrees. For now, the prediction assumes a very simple linear model, which might or might not reflect the actual trend.
#
# For this exercise, web query timeout should be temporarily increased to 30 seconds. This might take a while.

# %%
from astropy.utils.data import REMOTE_TIMEOUT

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    with REMOTE_TIMEOUT.set_temp(30):
        t_est, n_est = conesearch.predict_search(
            'http://gsss.stsci.edu/webservices/vo/ConeSearch.aspx?CAT=GSC23&',
            c, 0.5 * u.degree, verbose=False, plot=True)

# %%
print('Predicted run time is', t_est, 'seconds')
print('Predicted number of rows is', n_est)
# Out:
# Predicted run time is 37.4370998782 seconds
# Predicted number of rows is 42016

# %% [markdown]
# Let's get the actual run time and number of rows to compare with the prediction above. Since the predicted run time is longer than default timeout, we have to temporarily set the timeout to 60 seconds. This might take a while.
#
# As you will see, the prediction is not spot on, but it is not too shabby. Note that both predicted and actual run time results also depend on network latency and responsiveness of the service provider.

# %%
with REMOTE_TIMEOUT.set_temp(60):
    t_real, tab = conesearch.conesearch_timer(
        c, 0.5 * u.degree,
        catalog_db='http://gsss.stsci.edu/webservices/vo/ConeSearch.aspx?CAT=GSC23&',
        verbose=False)
# Out:
# INFO: conesearch_timer took 50.2119920254 s on AVERAGE for 1 call(s). [astropy.utils.timer]

# %%
print('Actual run time is', t_real, 'seconds')
print('Actual number of rows is', tab.nrows)
# Out:
# Actual run time is 50.2119920254 seconds
# Actual number of rows is 57255
